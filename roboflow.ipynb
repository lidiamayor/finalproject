# %%
from dotenv import load_dotenv
import os

# Load environment variables from a .env file
load_dotenv()

# Retrieve the API key from the environment variables
api_key = os.getenv("api_roboflow")

# %%
from roboflow import Roboflow
rf = Roboflow(api_key=api_key)
print(rf.workspace())
# Out:
# loading Roboflow workspace...
# {
#   "name": "Project",
#   "url": "project-gotd1",
#   "projects": [
#     "project-gotd1/attention-driving",
#     "project-gotd1/hard-hat-sample-urzfx"
#   ]
# }

# %% [markdown]
# ## DOWNLOAD DATASET

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="utAD4zpA7Eq60bHup1EE")
project = rf.workspace("project-gotd1").project("attention-driving")
version = project.version(11)
dataset = version.download("folder")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Exporting format folder in progress : 85.0%
# Version export complete for folder format
# Downloading Dataset Version Zip in Attention-driving-11 to folder:: 100%|██████████| 14943/14943 [00:01<00:00, 9303.39it/s]
# Extracting Dataset Version Zip to Attention-driving-11 in folder:: 100%|██████████| 805/805 [00:00<00:00, 2454.20it/s]

# %% [markdown]
# ## TRAIN THE MODEL - 2 CLASSIFICATION

# %%
from ultralytics import YOLO

# Load a pre-trained YOLOv5 classification model (smallest version)
model = YOLO('yolov8s-cls.pt')  # You can replace this with 'yolov5m-cls.pt', 'yolov5l-cls.pt', etc. for larger models.

# Train the model on your dataset
results = model.train(data='Attention-driving-3', epochs=10, imgsz=128)

model.save('model.pt')
# Out:
# Ultralytics 8.3.13  Python-3.11.10 torch-2.4.1+cpu CPU (11th Gen Intel Core(TM) i7-1165G7 2.80GHz)
# engine\trainer: task=classify, mode=train, model=yolov8s-cls.pt, data=Attention-driving-3, epochs=10, time=None, patience=100, batch=16, imgsz=128, save=True, save_period=-1, cache=False, device=None, workers=8, project=None, name=train2, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=True, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, bgr=0.0, mosaic=1.0, mixup=0.0, copy_paste=0.0, copy_paste_mode=flip, auto_augment=randaugment, erasing=0.4, crop_fraction=1.0, cfg=None, tracker=botsort.yaml, save_dir=runs\classify\train2
# train: C:\Users\Lidia Mayor\Documents\Data Analitycs\week8\proyectofinal\Attention-driving-3\train... found 252 images in 2 classes
# val: None...
# test: C:\Users\Lidia Mayor\Documents\Data Analitycs\week8\proyectofinal\Attention-driving-3\test... found 12 images in 2 classes
# Overriding model.yaml nc=1000 with nc=2
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     29056  ultralytics.nn.modules.block.C2f             [64, 64, 1, True]
#   3                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   4                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   5                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   6                  -1  2    788480  ultralytics.nn.modules.block.C2f             [256, 256, 2, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1838080  ultralytics.nn.modules.block.C2f             [512, 512, 1, True]
#   9                  -1  1    660482  ultralytics.nn.modules.head.Classify         [512, 2]
# YOLOv8s-cls summary: 99 layers, 5,083,298 parameters, 5,083,298 gradients, 12.6 GFLOPs
# Transferred 156/158 items from pretrained weights
# train: Scanning C:\Users\Lidia Mayor\Documents\Data Analitycs\week8\proyectofinal\Attention-driving-3\train... 252 images, 0 corrupt: 100%|██████████| 252/252 [00:00<?, ?it/s]
# val: Scanning C:\Users\Lidia Mayor\Documents\Data Analitycs\week8\proyectofinal\Attention-driving-3\test... 12 images, 0 corrupt: 100%|██████████| 12/12 [00:00<?, ?it/s]
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.000714, momentum=0.9) with parameter groups 26 weight(decay=0.0), 27 weight(decay=0.0005), 27 bias(decay=0.0)
# Image sizes 128 train, 128 val
# Using 0 dataloader workers
# Logging results to runs\classify\train2
# Starting training for 10 epochs...
#
#       Epoch    GPU_mem       loss  Instances       Size
#        1/10         0G     0.6423         12        128: 100%|██████████| 16/16 [00:06<00:00,  2.65it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00, 10.29it/s]
#                    all      0.917          1
#       Epoch    GPU_mem       loss  Instances       Size
#        2/10         0G     0.3905         12        128: 100%|██████████| 16/16 [00:05<00:00,  2.91it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00, 10.16it/s]
#                    all      0.917          1
#       Epoch    GPU_mem       loss  Instances       Size
#        3/10         0G     0.2412         12        128: 100%|██████████| 16/16 [00:09<00:00,  1.68it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,  4.73it/s]
#                    all      0.833          1
#       Epoch    GPU_mem       loss  Instances       Size
#        4/10         0G     0.1952         12        128: 100%|██████████| 16/16 [00:11<00:00,  1.33it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,  4.21it/s]
#                    all      0.917          1
#       Epoch    GPU_mem       loss  Instances       Size
#        5/10         0G     0.1244         12        128: 100%|██████████| 16/16 [00:10<00:00,  1.60it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,  3.23it/s]
#                    all      0.917          1
#       Epoch    GPU_mem       loss  Instances       Size
#        6/10         0G     0.1198         12        128: 100%|██████████| 16/16 [00:05<00:00,  3.12it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,  9.20it/s]
#                    all      0.917          1
#       Epoch    GPU_mem       loss  Instances       Size
#        7/10         0G    0.09774         12        128: 100%|██████████| 16/16 [00:04<00:00,  3.22it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00, 10.10it/s]
#                    all      0.917          1
#       Epoch    GPU_mem       loss  Instances       Size
#        8/10         0G       0.12         12        128: 100%|██████████| 16/16 [00:05<00:00,  3.07it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,  9.07it/s]
#                    all          1          1
#       Epoch    GPU_mem       loss  Instances       Size
#        9/10         0G    0.07539         12        128: 100%|██████████| 16/16 [00:08<00:00,  1.93it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,  9.28it/s]
#                    all          1          1
#       Epoch    GPU_mem       loss  Instances       Size
#       10/10         0G    0.05305         12        128: 100%|██████████| 16/16 [00:05<00:00,  3.14it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,  8.96it/s]
#                    all          1          1
# 10 epochs completed in 0.022 hours.
# Optimizer stripped from runs\classify\train2\weights\last.pt, 10.3MB
# Optimizer stripped from runs\classify\train2\weights\best.pt, 10.3MB
#
# Validating runs\classify\train2\weights\best.pt...
# Ultralytics 8.3.13  Python-3.11.10 torch-2.4.1+cpu CPU (11th Gen Intel Core(TM) i7-1165G7 2.80GHz)
# YOLOv8s-cls summary (fused): 73 layers, 5,077,762 parameters, 0 gradients, 12.4 GFLOPs
# WARNING  Dataset 'split=val' not found, using 'split=test' instead.
# train: C:\Users\Lidia Mayor\Documents\Data Analitycs\week8\proyectofinal\Attention-driving-3\train... found 252 images in 2 classes
# val: None...
# test: C:\Users\Lidia Mayor\Documents\Data Analitycs\week8\proyectofinal\Attention-driving-3\test... found 12 images in 2 classes
#                classes   top1_acc   top5_acc: 100%|██████████| 1/1 [00:00<00:00,  8.59it/s]
#                    all          1          1
# Speed: 0.0ms preprocess, 4.1ms inference, 0.0ms loss, 0.0ms postprocess per image
# Results saved to runs\classify\train2

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Make sure to use this line at the beginning of your notebook
# %matplotlib inline

confusion_matrix = results.confusion_matrix.matrix

# Plot the confusion matrix
plt.figure(figsize=(6, 5))
sns.heatmap(confusion_matrix, annot=True, cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

# %%
# Inference on a new image
results2 = model('image-1.jpg')

for result in results2:
    predicted_class = result.names[result.probs.top1]  # Class name of top prediction
    probability = result.probs.top1conf.item()  # Confidence score of top prediction

    print(f"Predicted Class: {predicted_class}, Probability: {probability:.4f}")
# Out:
# image 1/1 c:\Users\Lidia Mayor\Documents\Data Analitycs\week8\proyectofinal\image-1.jpg: 128x128 focus 0.99, distracted 0.01, 143.2ms
# Speed: 45.2ms preprocess, 143.2ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
# Predicted Class: focus, Probability: 0.9881

# %% [markdown]
# ## TRAIN THE MODEL - 3 CLASSIFICATION

# %%
from ultralytics import YOLO

# Load a pre-trained YOLOv5 classification model (smallest version)
model = YOLO('yolov8s-cls.pt')  # You can replace this with 'yolov5m-cls.pt', 'yolov5l-cls.pt', etc. for larger models.

# Train the model on your dataset
results = model.train(data='Attention-driving-11', epochs=14, imgsz=128)

model.save('model_3x3.pt')
# Out:
# New https://pypi.org/project/ultralytics/8.3.15 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.13  Python-3.11.10 torch-2.4.1+cpu CPU (11th Gen Intel Core(TM) i7-1165G7 2.80GHz)
# engine\trainer: task=classify, mode=train, model=yolov8s-cls.pt, data=Attention-driving-11, epochs=14, time=None, patience=100, batch=16, imgsz=128, save=True, save_period=-1, cache=False, device=None, workers=8, project=None, name=train18, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=True, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, bgr=0.0, mosaic=1.0, mixup=0.0, copy_paste=0.0, copy_paste_mode=flip, auto_augment=randaugment, erasing=0.4, crop_fraction=1.0, cfg=None, tracker=botsort.yaml, save_dir=runs\classify\train18
# train: C:\Users\Lidia Mayor\Documents\Data Analitycs\week8\proyectofinal\Attention-driving-11\train... found 693 images in 3 classes
# val: C:\Users\Lidia Mayor\Documents\Data Analitycs\week8\proyectofinal\Attention-driving-11\val... found 67 images in 3 classes
# test: C:\Users\Lidia Mayor\Documents\Data Analitycs\week8\proyectofinal\Attention-driving-11\test... found 31 images in 3 classes
# Overriding model.yaml nc=1000 with nc=3
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     29056  ultralytics.nn.modules.block.C2f             [64, 64, 1, True]
#   3                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   4                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   5                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   6                  -1  2    788480  ultralytics.nn.modules.block.C2f             [256, 256, 2, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1838080  ultralytics.nn.modules.block.C2f             [512, 512, 1, True]
#   9                  -1  1    661763  ultralytics.nn.modules.head.Classify         [512, 3]
# YOLOv8s-cls summary: 99 layers, 5,084,579 parameters, 5,084,579 gradients, 12.6 GFLOPs
# Transferred 156/158 items from pretrained weights
# train: Scanning C:\Users\Lidia Mayor\Documents\Data Analitycs\week8\proyectofinal\Attention-driving-11\train... 693 images, 0 corrupt: 100%|██████████| 693/693 [00:00<?, ?it/s]
# val: Scanning C:\Users\Lidia Mayor\Documents\Data Analitycs\week8\proyectofinal\Attention-driving-11\val... 67 images, 0 corrupt: 100%|██████████| 67/67 [00:00<?, ?it/s]
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.000714, momentum=0.9) with parameter groups 26 weight(decay=0.0), 27 weight(decay=0.0005), 27 bias(decay=0.0)
# Image sizes 128 train, 128 val
# Using 0 dataloader workers
# Logging results to runs\classify\train18
# Starting training for 14 epochs...
#
#       Epoch    GPU_mem       loss  Instances       Size
#        1/14         0G     0.9951          5        128: 100%|██████████| 44/44 [00:12<00:00,  3.40it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 3/3 [00:00<00:00,  6.18it/s]
#                    all      0.657          1
#       Epoch    GPU_mem       loss  Instances       Size
#        2/14         0G     0.6634          5        128: 100%|██████████| 44/44 [00:12<00:00,  3.48it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 3/3 [00:00<00:00,  5.00it/s]
#                    all      0.806          1
#       Epoch    GPU_mem       loss  Instances       Size
#        3/14         0G     0.4466          5        128: 100%|██████████| 44/44 [00:12<00:00,  3.46it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 3/3 [00:00<00:00,  5.88it/s]
#                    all      0.776          1
#       Epoch    GPU_mem       loss  Instances       Size
#        4/14         0G     0.3343          5        128: 100%|██████████| 44/44 [00:11<00:00,  3.75it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 3/3 [00:00<00:00,  6.09it/s]
#                    all      0.806          1
#       Epoch    GPU_mem       loss  Instances       Size
#        5/14         0G     0.2744          5        128: 100%|██████████| 44/44 [00:11<00:00,  3.90it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 3/3 [00:00<00:00,  6.23it/s]
#                    all      0.836          1
#       Epoch    GPU_mem       loss  Instances       Size
#        6/14         0G     0.2534          5        128: 100%|██████████| 44/44 [00:11<00:00,  3.91it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 3/3 [00:00<00:00,  6.23it/s]
#                    all      0.866          1
#       Epoch    GPU_mem       loss  Instances       Size
#        7/14         0G      0.187          5        128: 100%|██████████| 44/44 [00:11<00:00,  3.89it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 3/3 [00:00<00:00,  6.24it/s]
#                    all      0.881          1
#       Epoch    GPU_mem       loss  Instances       Size
#        8/14         0G     0.1864          5        128: 100%|██████████| 44/44 [00:11<00:00,  3.88it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 3/3 [00:00<00:00,  6.22it/s]
#                    all      0.896          1
#       Epoch    GPU_mem       loss  Instances       Size
#        9/14         0G     0.1936          5        128: 100%|██████████| 44/44 [00:11<00:00,  3.90it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 3/3 [00:00<00:00,  6.23it/s]
#                    all      0.821          1
#       Epoch    GPU_mem       loss  Instances       Size
#       10/14         0G     0.1365          5        128: 100%|██████████| 44/44 [00:11<00:00,  3.74it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 3/3 [00:00<00:00,  6.19it/s]
#                    all      0.866          1
#       Epoch    GPU_mem       loss  Instances       Size
#       11/14         0G     0.1269          5        128: 100%|██████████| 44/44 [00:12<00:00,  3.46it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 3/3 [00:00<00:00,  5.44it/s]
#                    all      0.866          1
#       Epoch    GPU_mem       loss  Instances       Size
#       12/14         0G     0.1702          5        128: 100%|██████████| 44/44 [00:12<00:00,  3.43it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 3/3 [00:00<00:00,  4.31it/s]
#                    all      0.866          1
#       Epoch    GPU_mem       loss  Instances       Size
#       13/14         0G     0.1299          5        128: 100%|██████████| 44/44 [00:14<00:00,  3.02it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 3/3 [00:00<00:00,  5.87it/s]
#                    all      0.866          1
#       Epoch    GPU_mem       loss  Instances       Size
#       14/14         0G     0.1158          5        128: 100%|██████████| 44/44 [00:15<00:00,  2.89it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 3/3 [00:00<00:00,  5.02it/s]
#                    all      0.866          1
# 14 epochs completed in 0.052 hours.
# Optimizer stripped from runs\classify\train18\weights\last.pt, 10.3MB
# Optimizer stripped from runs\classify\train18\weights\best.pt, 10.3MB
#
# Validating runs\classify\train18\weights\best.pt...
# Ultralytics 8.3.13  Python-3.11.10 torch-2.4.1+cpu CPU (11th Gen Intel Core(TM) i7-1165G7 2.80GHz)
# YOLOv8s-cls summary (fused): 73 layers, 5,079,043 parameters, 0 gradients, 12.5 GFLOPs
# train: C:\Users\Lidia Mayor\Documents\Data Analitycs\week8\proyectofinal\Attention-driving-11\train... found 693 images in 3 classes
# val: C:\Users\Lidia Mayor\Documents\Data Analitycs\week8\proyectofinal\Attention-driving-11\val... found 67 images in 3 classes
# test: C:\Users\Lidia Mayor\Documents\Data Analitycs\week8\proyectofinal\Attention-driving-11\test... found 31 images in 3 classes
#                classes   top1_acc   top5_acc: 100%|██████████| 3/3 [00:00<00:00,  6.05it/s]
#                    all      0.896          1
# Speed: 0.0ms preprocess, 2.9ms inference, 0.0ms loss, 0.0ms postprocess per image
# Results saved to runs\classify\train18

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Make sure to use this line at the beginning of your notebook
# %matplotlib inline

confusion_matrix = results.confusion_matrix.matrix

# Plot the confusion matrix
plt.figure(figsize=(6, 5))
sns.heatmap(confusion_matrix, annot=True, cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

# %%
# Inference on a new image
results2 = model('image-1.jpg')

for result in results2:
    predicted_class = result.names[result.probs.top1]  # Class name of top prediction
    probability = result.probs.top1conf.item()  # Confidence score of top prediction

    print(f"Predicted Class: {predicted_class}, Probability: {probability:.4f}")
# Out:
# image 1/1 c:\Users\Lidia Mayor\Documents\Data Analitycs\week8\proyectofinal\image-1.jpg: 128x128 focus 1.00, distracted 0.00, tired 0.00, 12.3ms
# Speed: 8.0ms preprocess, 12.3ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
# Predicted Class: focus, Probability: 0.9997

# %%
import cv2

# Inicializar la cámara
cap = cv2.VideoCapture(0)

while True:
    ret, frame = cap.read()
    if not ret:
        print("Error al capturar el video")
        break

    # Aquí puedes agregar el procesamiento de tu modelo, por ejemplo, detección con YOLO

    cv2.imshow('Deteccion de Fatiga', frame)

    # Presionar 'q' para salir del loop
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()

# %%
import cv2
import pandas as pd
import time
from datetime import datetime
from ultralytics import YOLO
import winsound

# Inicializar YOLO con tu modelo personalizado
model = YOLO('model/model_3x2.pt')

# Inicializar el DataFrame para almacenar el historial de predicciones
df = pd.DataFrame(columns=["timestamp", "estate", "probability"])

# Función para guardar las predicciones en el DataFrame
def guardar_prediccion(prediccion, probabilidad):
    global df
    timestamp = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
    nueva_fila = pd.DataFrame([[timestamp, prediccion, probabilidad]], columns=["timestamp", "estate", "probability"])
    df = pd.concat([df, nueva_fila], ignore_index=True)

# Función para lanzar una alerta sonora
def alerta_sonora():
    print("¡ALERTA! El conductor ha estado cansado por más de 2 segundos consecutivos.")
    winsound.Beep(1000, 1000)  # Sonido a 1000 Hz durante 1 segundo

# Inicializamos el contador de tiempo consecutivo de "tired"
contador_cansado = 0
umbral_alerta = 2  # Umbral de 2 segundos para generar alerta
intervalo_frame = 0.1  # Suponemos que las predicciones se generan cada 100 ms (0.1 segundos)

# Capturar video de la cámara
cap = cv2.VideoCapture(0)

while True:
    ret, frame = cap.read()
    if not ret:
        break

    # Procesar el frame con YOLO
    results = model(frame)

    # Obtener las detecciones
    detections = results[0].names[results[0].probs.top1]
    probabilidad = results[0].probs.top1conf.item()  # Obtener la probabilidad más alta de la predicción

    # Guardar la predicción en el DataFrame
    guardar_prediccion(detections, probabilidad)

    # Verificar si el estado actual es "tired"
    if detections == "tired":
        contador_cansado += intervalo_frame  # Aumentamos el contador en 0.1 segundos
    else:
        contador_cansado = 0  # Si no está cansado, reiniciamos el contador

    # Si el conductor ha estado "tired" por más de 2 segundos, generamos una alerta
    if contador_cansado >= umbral_alerta:
        alerta_sonora()
        contador_cansado = 0  # Reiniciar el contador tras la alerta para evitar repetidas alertas

    # Mostrar el estado en la ventana de video
    cv2.putText(frame, detections, (50, 50), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2)
    cv2.imshow('Detección de Fatiga', frame)

    # Presionar 'q' para salir del loop
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()

# Guardar el DataFrame en un archivo CSV para análisis posterior si es necesario
df.to_csv("historial_predicciones.csv", index=False)
# Out:
# 0: 128x128 tired 0.71, focus 0.26, distracted 0.03, 0.0ms
# Speed: 5.3ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.90, tired 0.09, distracted 0.01, 0.0ms
# Speed: 7.1ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.57, tired 0.42, distracted 0.01, 3.0ms
# Speed: 5.3ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.77, tired 0.22, distracted 0.01, 0.0ms
# Speed: 0.0ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.68, focus 0.29, distracted 0.03, 10.7ms
# Speed: 2.2ms preprocess, 10.7ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
# C:\Users\Lidia Mayor\AppData\Local\Temp\ipykernel_1472\1775827979.py:19: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df, nueva_fila], ignore_index=True)
# 0: 128x128 tired 0.98, focus 0.02, distracted 0.00, 5.5ms
# Speed: 0.1ms preprocess, 5.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.95, focus 0.04, distracted 0.00, 12.1ms
# Speed: 0.0ms preprocess, 12.1ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.95, focus 0.04, distracted 0.01, 11.5ms
# Speed: 0.0ms preprocess, 11.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.95, focus 0.04, distracted 0.01, 0.0ms
# Speed: 0.0ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.97, distracted 0.02, focus 0.01, 0.0ms
# Speed: 0.0ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.94, focus 0.04, distracted 0.02, 8.5ms
# Speed: 0.0ms preprocess, 8.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.83, focus 0.15, distracted 0.02, 0.0ms
# Speed: 0.0ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.79, tired 0.19, distracted 0.01, 0.0ms
# Speed: 0.0ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.90, tired 0.10, distracted 0.01, 8.5ms
# Speed: 0.0ms preprocess, 8.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.81, tired 0.17, distracted 0.02, 0.0ms
# Speed: 2.0ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.73, tired 0.24, distracted 0.02, 0.0ms
# Speed: 0.0ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.78, tired 0.17, distracted 0.05, 11.1ms
# Speed: 0.0ms preprocess, 11.1ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.93, tired 0.06, distracted 0.01, 12.2ms
# Speed: 0.0ms preprocess, 12.2ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.97, tired 0.02, distracted 0.01, 11.7ms
# Speed: 0.0ms preprocess, 11.7ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.97, tired 0.02, distracted 0.01, 11.4ms
# Speed: 0.0ms preprocess, 11.4ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.96, tired 0.04, distracted 0.01, 0.0ms
# Speed: 0.0ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.95, tired 0.04, distracted 0.01, 0.0ms
# Speed: 0.0ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.95, tired 0.03, distracted 0.01, 8.5ms
# Speed: 0.0ms preprocess, 8.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.94, tired 0.05, distracted 0.01, 0.0ms
# Speed: 2.5ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.98, tired 0.02, distracted 0.01, 0.0ms
# Speed: 0.0ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.98, tired 0.01, distracted 0.01, 1.4ms
# Speed: 5.3ms preprocess, 1.4ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.97, tired 0.02, distracted 0.01, 10.1ms
# Speed: 0.0ms preprocess, 10.1ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.98, tired 0.02, distracted 0.00, 8.5ms
# Speed: 2.0ms preprocess, 8.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.97, tired 0.03, distracted 0.01, 9.8ms
# Speed: 0.0ms preprocess, 9.8ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.97, tired 0.02, distracted 0.01, 12.4ms
# Speed: 0.0ms preprocess, 12.4ms inference, 0.6ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.97, tired 0.02, distracted 0.01, 0.0ms
# Speed: 0.0ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.99, tired 0.01, distracted 0.01, 3.0ms
# Speed: 2.0ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.99, tired 0.00, distracted 0.00, 0.0ms
# Speed: 0.0ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.99, tired 0.01, distracted 0.00, 0.0ms
# Speed: 0.0ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.99, tired 0.01, distracted 0.01, 7.5ms
# Speed: 0.0ms preprocess, 7.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.98, tired 0.01, distracted 0.01, 0.0ms
# Speed: 1.5ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.98, tired 0.01, distracted 0.01, 0.0ms
# Speed: 0.0ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.98, tired 0.01, distracted 0.01, 7.5ms
# Speed: 0.0ms preprocess, 7.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.98, tired 0.01, distracted 0.01, 0.0ms
# Speed: 2.5ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.96, tired 0.02, distracted 0.01, 0.0ms
# Speed: 0.0ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.93, tired 0.05, distracted 0.02, 9.0ms
# Speed: 0.0ms preprocess, 9.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.91, tired 0.08, distracted 0.02, 0.0ms
# Speed: 1.5ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.98, tired 0.01, distracted 0.01, 0.0ms
# Speed: 0.0ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.91, tired 0.07, distracted 0.03, 11.9ms
# Speed: 0.0ms preprocess, 11.9ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.91, tired 0.07, distracted 0.02, 11.9ms
# Speed: 0.0ms preprocess, 11.9ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.96, tired 0.03, distracted 0.01, 0.0ms
# Speed: 0.0ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.98, tired 0.01, distracted 0.01, 5.0ms
# Speed: 3.4ms preprocess, 5.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.98, tired 0.02, distracted 0.01, 10.3ms
# Speed: 0.5ms preprocess, 10.3ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.94, tired 0.05, distracted 0.01, 5.0ms
# Speed: 2.3ms preprocess, 5.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.95, tired 0.03, distracted 0.02, 6.0ms
# Speed: 2.0ms preprocess, 6.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.90, tired 0.07, distracted 0.03, 0.0ms
# Speed: 1.6ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.79, tired 0.17, distracted 0.05, 0.0ms
# Speed: 0.0ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.88, tired 0.08, distracted 0.04, 6.0ms
# Speed: 0.0ms preprocess, 6.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.89, tired 0.08, distracted 0.03, 0.0ms
# Speed: 0.0ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.96, tired 0.03, distracted 0.01, 0.0ms
# Speed: 0.0ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.93, tired 0.05, distracted 0.02, 8.6ms
# Speed: 4.4ms preprocess, 8.6ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.51, focus 0.44, distracted 0.05, 0.0ms
# Speed: 2.0ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.64, focus 0.33, distracted 0.03, 0.0ms
# Speed: 1.9ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.63, focus 0.32, distracted 0.05, 8.0ms
# Speed: 0.0ms preprocess, 8.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.62, tired 0.32, distracted 0.06, 0.0ms
# Speed: 3.5ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.73, tired 0.23, distracted 0.04, 0.0ms
# Speed: 0.0ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.85, tired 0.12, distracted 0.03, 7.5ms
# Speed: 0.0ms preprocess, 7.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.92, tired 0.07, distracted 0.01, 0.0ms
# Speed: 2.5ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.97, tired 0.02, distracted 0.01, 0.0ms
# Speed: 0.0ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.97, tired 0.02, distracted 0.01, 9.0ms
# Speed: 0.0ms preprocess, 9.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.97, tired 0.02, distracted 0.01, 0.0ms
# Speed: 1.5ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.98, tired 0.01, distracted 0.01, 0.0ms
# Speed: 0.0ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.94, tired 0.05, distracted 0.01, 8.5ms
# Speed: 0.0ms preprocess, 8.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.94, tired 0.05, distracted 0.02, 0.0ms
# Speed: 2.5ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.96, tired 0.03, distracted 0.02, 0.0ms
# Speed: 0.0ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.94, tired 0.03, distracted 0.03, 7.5ms
# Speed: 0.0ms preprocess, 7.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.91, tired 0.05, distracted 0.04, 0.0ms
# Speed: 3.0ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.89, tired 0.06, distracted 0.05, 1.0ms
# Speed: 3.0ms preprocess, 1.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.82, tired 0.10, distracted 0.07, 7.5ms
# Speed: 0.0ms preprocess, 7.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.80, tired 0.13, distracted 0.07, 7.6ms
# Speed: 2.5ms preprocess, 7.6ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.82, tired 0.11, distracted 0.07, 0.0ms
# Speed: 0.0ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.45, tired 0.37, distracted 0.17, 8.7ms
# Speed: 0.0ms preprocess, 8.7ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.72, distracted 0.17, focus 0.11, 0.0ms
# Speed: 4.0ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.72, distracted 0.21, focus 0.07, 0.0ms
# Speed: 0.0ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.52, distracted 0.41, focus 0.07, 7.5ms
# Speed: 0.0ms preprocess, 7.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.58, tired 0.40, focus 0.02, 11.6ms
# Speed: 2.0ms preprocess, 11.6ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.84, tired 0.15, focus 0.01, 0.0ms
# Speed: 0.0ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.96, tired 0.04, focus 0.01, 7.5ms
# Speed: 0.0ms preprocess, 7.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.98, tired 0.02, focus 0.00, 0.0ms
# Speed: 2.0ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.96, tired 0.04, focus 0.00, 0.0ms
# Speed: 0.0ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.91, tired 0.09, focus 0.00, 6.5ms
# Speed: 0.0ms preprocess, 6.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.99, tired 0.01, focus 0.00, 0.0ms
# Speed: 4.0ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.99, tired 0.00, focus 0.00, 0.0ms
# Speed: 0.0ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 1.00, tired 0.00, focus 0.00, 9.0ms
# Speed: 0.0ms preprocess, 9.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 1.00, tired 0.00, focus 0.00, 0.0ms
# Speed: 4.5ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 1.00, tired 0.00, focus 0.00, 0.0ms
# Speed: 0.0ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 1.00, tired 0.00, focus 0.00, 8.5ms
# Speed: 0.0ms preprocess, 8.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 1.00, tired 0.00, focus 0.00, 0.0ms
# Speed: 4.5ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 1.00, tired 0.00, focus 0.00, 0.0ms
# Speed: 0.0ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 1.00, tired 0.00, focus 0.00, 0.0ms
# Speed: 0.0ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 1.00, tired 0.00, focus 0.00, 6.5ms
# Speed: 0.0ms preprocess, 6.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 1.00, tired 0.00, focus 0.00, 0.0ms
# Speed: 2.3ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 1.00, tired 0.00, focus 0.00, 9.0ms
# Speed: 0.0ms preprocess, 9.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 1.00, tired 0.00, focus 0.00, 0.0ms
# Speed: 4.5ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 1.00, tired 0.00, focus 0.00, 0.0ms
# Speed: 0.0ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.97, tired 0.03, focus 0.00, 7.0ms
# Speed: 0.0ms preprocess, 7.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.97, tired 0.03, focus 0.00, 0.0ms
# Speed: 4.5ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.85, tired 0.13, focus 0.02, 0.0ms
# Speed: 0.0ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.66, tired 0.27, focus 0.07, 8.4ms
# Speed: 0.0ms preprocess, 8.4ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.58, tired 0.36, focus 0.06, 0.0ms
# Speed: 4.5ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.54, distracted 0.32, focus 0.14, 0.0ms
# Speed: 0.0ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.55, focus 0.25, distracted 0.20, 3.5ms
# Speed: 2.9ms preprocess, 3.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.55, focus 0.25, distracted 0.20, 0.0ms
# Speed: 3.4ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.46, tired 0.30, focus 0.24, 5.0ms
# Speed: 2.4ms preprocess, 5.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.54, tired 0.33, focus 0.14, 0.0ms
# Speed: 4.0ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.46, distracted 0.41, focus 0.13, 0.0ms
# Speed: 0.6ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.55, tired 0.29, focus 0.16, 7.0ms
# Speed: 0.0ms preprocess, 7.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.40, focus 0.37, tired 0.23, 5.0ms
# Speed: 0.0ms preprocess, 5.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.54, distracted 0.27, tired 0.19, 0.0ms
# Speed: 0.0ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.47, focus 0.40, tired 0.13, 7.5ms
# Speed: 1.8ms preprocess, 7.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.51, focus 0.38, tired 0.11, 0.0ms
# Speed: 3.5ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.61, tired 0.20, focus 0.19, 0.0ms
# Speed: 0.0ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.53, distracted 0.32, focus 0.15, 7.0ms
# Speed: 0.0ms preprocess, 7.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.50, distracted 0.48, focus 0.02, 5.5ms
# Speed: 0.0ms preprocess, 5.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.52, distracted 0.46, focus 0.02, 0.0ms
# Speed: 0.0ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.52, distracted 0.46, focus 0.02, 8.5ms
# Speed: 0.0ms preprocess, 8.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.59, distracted 0.40, focus 0.01, 3.0ms
# Speed: 2.3ms preprocess, 3.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.94, tired 0.06, focus 0.00, 0.0ms
# Speed: 0.0ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.97, tired 0.03, focus 0.00, 6.7ms
# Speed: 0.0ms preprocess, 6.7ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.97, tired 0.03, focus 0.00, 5.5ms
# Speed: 0.0ms preprocess, 5.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.96, tired 0.03, focus 0.01, 0.0ms
# Speed: 0.0ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.99, tired 0.01, focus 0.00, 6.7ms
# Speed: 0.0ms preprocess, 6.7ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.99, tired 0.01, focus 0.00, 0.0ms
# Speed: 4.5ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.98, tired 0.02, focus 0.00, 0.0ms
# Speed: 0.0ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.95, tired 0.04, focus 0.00, 11.5ms
# Speed: 0.0ms preprocess, 11.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.97, tired 0.02, focus 0.01, 0.0ms
# Speed: 3.5ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.97, tired 0.02, focus 0.01, 0.0ms
# Speed: 0.0ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.97, tired 0.02, focus 0.01, 8.5ms
# Speed: 0.0ms preprocess, 8.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.97, tired 0.02, focus 0.01, 6.0ms
# Speed: 0.0ms preprocess, 6.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.99, tired 0.01, focus 0.00, 9.7ms
# Speed: 3.4ms preprocess, 9.7ms inference, 0.7ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.98, tired 0.01, focus 0.00, 7.5ms
# Speed: 0.0ms preprocess, 7.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.98, tired 0.02, focus 0.00, 6.0ms
# Speed: 0.0ms preprocess, 6.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.98, tired 0.02, focus 0.00, 0.0ms
# Speed: 0.0ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.95, tired 0.05, focus 0.01, 9.0ms
# Speed: 0.0ms preprocess, 9.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.88, tired 0.11, focus 0.01, 0.0ms
# Speed: 4.1ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.88, tired 0.10, focus 0.02, 8.5ms
# Speed: 0.0ms preprocess, 8.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.92, tired 0.06, focus 0.01, 0.0ms
# Speed: 0.0ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.78, distracted 0.17, focus 0.05, 0.0ms
# Speed: 0.0ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.80, distracted 0.16, focus 0.04, 8.5ms
# Speed: 0.0ms preprocess, 8.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.71, distracted 0.24, focus 0.05, 0.0ms
# Speed: 4.3ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.71, distracted 0.24, focus 0.05, 7.7ms
# Speed: 0.0ms preprocess, 7.7ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.73, distracted 0.20, focus 0.07, 8.7ms
# Speed: 0.0ms preprocess, 8.7ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.89, distracted 0.08, focus 0.03, 0.0ms
# Speed: 3.1ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.95, distracted 0.04, focus 0.01, 0.0ms
# Speed: 2.9ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.96, distracted 0.03, focus 0.01, 9.0ms
# Speed: 0.0ms preprocess, 9.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.95, distracted 0.04, focus 0.01, 0.0ms
# Speed: 0.0ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.90, focus 0.05, distracted 0.05, 0.0ms
# Speed: 1.7ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.69, focus 0.17, distracted 0.14, 7.5ms
# Speed: 0.0ms preprocess, 7.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.44, focus 0.39, distracted 0.17, 0.0ms
# Speed: 3.0ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.46, tired 0.43, distracted 0.11, 0.0ms
# Speed: 0.0ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.68, focus 0.21, distracted 0.11, 5.0ms
# Speed: 3.5ms preprocess, 5.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.71, focus 0.20, distracted 0.09, 1.1ms
# Speed: 4.1ms preprocess, 1.1ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.46, focus 0.39, distracted 0.15, 0.0ms
# Speed: 5.0ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.46, focus 0.39, distracted 0.15, 4.6ms
# Speed: 0.0ms preprocess, 4.6ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.87, distracted 0.08, tired 0.05, 0.0ms
# Speed: 4.0ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.94, distracted 0.04, tired 0.01, 0.0ms
# Speed: 1.0ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.93, distracted 0.05, tired 0.02, 4.5ms
# Speed: 3.8ms preprocess, 4.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.86, distracted 0.08, tired 0.07, 0.0ms
# Speed: 0.0ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.79, tired 0.18, distracted 0.03, 7.5ms
# Speed: 0.0ms preprocess, 7.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.68, focus 0.23, distracted 0.09, 6.0ms
# Speed: 0.0ms preprocess, 6.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.89, distracted 0.10, focus 0.01, 8.1ms
# Speed: 5.6ms preprocess, 8.1ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.96, distracted 0.03, focus 0.00, 12.8ms
# Speed: 2.4ms preprocess, 12.8ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.95, distracted 0.05, focus 0.00, 7.0ms
# Speed: 3.2ms preprocess, 7.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.96, distracted 0.04, focus 0.00, 0.0ms
# Speed: 0.6ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.96, distracted 0.04, focus 0.00, 0.0ms
# Speed: 4.8ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.95, distracted 0.04, focus 0.00, 6.5ms
# Speed: 0.0ms preprocess, 6.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.95, distracted 0.04, focus 0.00, 1.0ms
# Speed: 3.8ms preprocess, 1.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.96, distracted 0.04, focus 0.00, 0.0ms
# Speed: 4.0ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.96, distracted 0.04, focus 0.00, 6.0ms
# Speed: 1.0ms preprocess, 6.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.98, distracted 0.02, focus 0.00, 0.0ms
# Speed: 1.2ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.97, distracted 0.02, focus 0.00, 0.0ms
# Speed: 0.0ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.99, distracted 0.01, focus 0.00, 8.5ms
# Speed: 0.0ms preprocess, 8.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.98, distracted 0.02, focus 0.00, 0.0ms
# Speed: 0.0ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.99, distracted 0.01, focus 0.00, 0.0ms
# Speed: 2.3ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.98, distracted 0.02, focus 0.00, 9.0ms
# Speed: 0.0ms preprocess, 9.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.98, distracted 0.02, focus 0.00, 0.0ms
# Speed: 0.0ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.97, distracted 0.03, focus 0.00, 0.0ms
# Speed: 0.0ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.97, distracted 0.03, focus 0.00, 9.4ms
# Speed: 0.0ms preprocess, 9.4ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.97, distracted 0.03, focus 0.00, 9.8ms
# Speed: 0.0ms preprocess, 9.8ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
# ¡ALERTA! El conductor ha estado cansado por más de 2 segundos consecutivos.
#
# 0: 128x128 tired 0.90, distracted 0.08, focus 0.02, 11.6ms
# Speed: 0.0ms preprocess, 11.6ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.88, distracted 0.10, focus 0.02, 8.4ms
# Speed: 2.8ms preprocess, 8.4ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.81, distracted 0.16, focus 0.03, 11.0ms
# Speed: 0.0ms preprocess, 11.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.55, distracted 0.39, focus 0.06, 11.7ms
# Speed: 0.0ms preprocess, 11.7ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.50, tired 0.48, focus 0.03, 6.4ms
# Speed: 0.0ms preprocess, 6.4ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.64, tired 0.35, focus 0.02, 7.0ms
# Speed: 0.0ms preprocess, 7.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.70, tired 0.29, focus 0.01, 9.4ms
# Speed: 0.0ms preprocess, 9.4ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.72, tired 0.28, focus 0.00, 7.7ms
# Speed: 3.0ms preprocess, 7.7ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.72, tired 0.28, focus 0.00, 7.0ms
# Speed: 3.0ms preprocess, 7.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.66, tired 0.34, focus 0.00, 0.0ms
# Speed: 1.0ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.54, tired 0.46, focus 0.00, 8.0ms
# Speed: 0.0ms preprocess, 8.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.59, tired 0.41, focus 0.00, 7.3ms
# Speed: 4.1ms preprocess, 7.3ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.50, distracted 0.49, focus 0.00, 6.0ms
# Speed: 4.4ms preprocess, 6.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.72, tired 0.28, focus 0.01, 7.4ms
# Speed: 5.1ms preprocess, 7.4ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.79, tired 0.21, focus 0.00, 6.6ms
# Speed: 3.1ms preprocess, 6.6ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.78, tired 0.22, focus 0.00, 0.0ms
# Speed: 0.0ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.69, tired 0.31, focus 0.00, 8.5ms
# Speed: 0.0ms preprocess, 8.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.81, tired 0.18, focus 0.00, 7.0ms
# Speed: 3.4ms preprocess, 7.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.94, tired 0.06, focus 0.00, 0.0ms
# Speed: 0.0ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.90, tired 0.10, focus 0.00, 8.4ms
# Speed: 2.0ms preprocess, 8.4ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.88, tired 0.12, focus 0.00, 6.8ms
# Speed: 3.0ms preprocess, 6.8ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.88, tired 0.12, focus 0.00, 0.0ms
# Speed: 1.0ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.88, tired 0.12, focus 0.00, 8.5ms
# Speed: 0.0ms preprocess, 8.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.88, tired 0.11, focus 0.00, 6.0ms
# Speed: 3.0ms preprocess, 6.0ms inference, 1.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.91, tired 0.09, focus 0.00, 0.0ms
# Speed: 0.0ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.92, tired 0.08, focus 0.00, 7.5ms
# Speed: 0.0ms preprocess, 7.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.91, tired 0.09, focus 0.00, 7.0ms
# Speed: 3.6ms preprocess, 7.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.93, tired 0.07, focus 0.00, 0.0ms
# Speed: 3.2ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.89, tired 0.10, focus 0.00, 1.7ms
# Speed: 3.8ms preprocess, 1.7ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.91, tired 0.09, focus 0.00, 6.3ms
# Speed: 3.4ms preprocess, 6.3ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.77, tired 0.23, focus 0.00, 3.8ms
# Speed: 3.2ms preprocess, 3.8ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.62, tired 0.38, focus 0.01, 3.2ms
# Speed: 4.0ms preprocess, 3.2ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.68, tired 0.31, focus 0.01, 5.6ms
# Speed: 3.0ms preprocess, 5.6ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.68, tired 0.31, focus 0.01, 0.0ms
# Speed: 0.0ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.67, distracted 0.32, focus 0.01, 7.0ms
# Speed: 0.0ms preprocess, 7.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.72, distracted 0.26, focus 0.02, 6.0ms
# Speed: 3.0ms preprocess, 6.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.48, tired 0.45, focus 0.07, 0.0ms
# Speed: 0.0ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.53, tired 0.37, focus 0.10, 8.0ms
# Speed: 0.0ms preprocess, 8.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.54, distracted 0.39, focus 0.07, 6.0ms
# Speed: 3.0ms preprocess, 6.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.51, distracted 0.39, focus 0.10, 0.0ms
# Speed: 0.0ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.47, distracted 0.39, focus 0.13, 8.0ms
# Speed: 0.0ms preprocess, 8.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.51, tired 0.44, focus 0.05, 6.0ms
# Speed: 3.0ms preprocess, 6.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.65, distracted 0.33, focus 0.02, 0.0ms
# Speed: 0.0ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.81, distracted 0.18, focus 0.01, 6.0ms
# Speed: 2.2ms preprocess, 6.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.69, distracted 0.28, focus 0.04, 2.2ms
# Speed: 3.1ms preprocess, 2.2ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.63, distracted 0.31, focus 0.06, 11.1ms
# Speed: 0.0ms preprocess, 11.1ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.63, distracted 0.31, focus 0.06, 8.5ms
# Speed: 0.0ms preprocess, 8.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.81, distracted 0.16, focus 0.03, 7.0ms
# Speed: 4.0ms preprocess, 7.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.72, distracted 0.26, focus 0.03, 0.0ms
# Speed: 0.0ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.49, tired 0.48, focus 0.03, 8.5ms
# Speed: 0.0ms preprocess, 8.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.66, distracted 0.33, focus 0.01, 7.0ms
# Speed: 3.0ms preprocess, 7.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.76, distracted 0.24, focus 0.01, 0.0ms
# Speed: 0.0ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.54, distracted 0.45, focus 0.01, 2.4ms
# Speed: 3.0ms preprocess, 2.4ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.94, tired 0.05, focus 0.01, 11.1ms
# Speed: 3.5ms preprocess, 11.1ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.98, tired 0.01, focus 0.01, 7.0ms
# Speed: 5.5ms preprocess, 7.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.99, tired 0.01, focus 0.00, 8.0ms
# Speed: 0.0ms preprocess, 8.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.98, tired 0.02, focus 0.00, 6.0ms
# Speed: 3.2ms preprocess, 6.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.99, tired 0.01, focus 0.00, 0.0ms
# Speed: 0.0ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.98, tired 0.01, focus 0.00, 6.0ms
# Speed: 0.0ms preprocess, 6.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.98, tired 0.01, focus 0.00, 7.0ms
# Speed: 3.0ms preprocess, 7.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.98, tired 0.02, focus 0.00, 0.0ms
# Speed: 0.0ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.97, tired 0.03, focus 0.00, 8.5ms
# Speed: 0.0ms preprocess, 8.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.95, tired 0.04, focus 0.01, 7.0ms
# Speed: 3.0ms preprocess, 7.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.97, tired 0.03, focus 0.01, 0.0ms
# Speed: 0.0ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.92, tired 0.07, focus 0.01, 9.0ms
# Speed: 0.0ms preprocess, 9.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.96, tired 0.03, focus 0.01, 8.0ms
# Speed: 3.1ms preprocess, 8.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.99, tired 0.01, focus 0.00, 7.1ms
# Speed: 0.0ms preprocess, 7.1ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.98, tired 0.01, focus 0.00, 6.0ms
# Speed: 3.1ms preprocess, 6.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.99, tired 0.01, focus 0.00, 11.0ms
# Speed: 0.0ms preprocess, 11.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.99, tired 0.01, focus 0.00, 8.0ms
# Speed: 3.0ms preprocess, 8.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.98, tired 0.02, focus 0.00, 5.5ms
# Speed: 0.0ms preprocess, 5.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.99, tired 0.01, focus 0.00, 7.1ms
# Speed: 3.0ms preprocess, 7.1ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.98, tired 0.02, focus 0.00, 0.0ms
# Speed: 4.7ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.98, tired 0.01, focus 0.00, 2.5ms
# Speed: 5.5ms preprocess, 2.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.99, tired 0.01, focus 0.00, 7.0ms
# Speed: 3.0ms preprocess, 7.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.98, tired 0.01, focus 0.01, 0.0ms
# Speed: 0.0ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.96, tired 0.03, focus 0.01, 8.5ms
# Speed: 0.0ms preprocess, 8.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.80, tired 0.20, focus 0.01, 7.2ms
# Speed: 4.6ms preprocess, 7.2ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.88, tired 0.11, focus 0.00, 0.0ms
# Speed: 0.0ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.69, tired 0.31, focus 0.01, 9.0ms
# Speed: 0.0ms preprocess, 9.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.61, distracted 0.38, focus 0.01, 7.0ms
# Speed: 3.0ms preprocess, 7.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.55, distracted 0.43, focus 0.02, 0.0ms
# Speed: 0.0ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.94, distracted 0.06, focus 0.01, 9.0ms
# Speed: 0.0ms preprocess, 9.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.85, distracted 0.13, focus 0.01, 7.0ms
# Speed: 3.0ms preprocess, 7.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.92, distracted 0.06, focus 0.02, 0.0ms
# Speed: 0.0ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.94, distracted 0.05, focus 0.01, 7.5ms
# Speed: 0.0ms preprocess, 7.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.97, distracted 0.03, focus 0.00, 6.0ms
# Speed: 3.0ms preprocess, 6.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.99, distracted 0.01, focus 0.00, 0.0ms
# Speed: 0.0ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.98, distracted 0.02, focus 0.01, 9.0ms
# Speed: 0.0ms preprocess, 9.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.97, distracted 0.02, focus 0.01, 6.0ms
# Speed: 3.0ms preprocess, 6.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.92, distracted 0.05, focus 0.03, 0.0ms
# Speed: 0.0ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.94, distracted 0.03, focus 0.02, 9.0ms
# Speed: 0.0ms preprocess, 9.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.96, distracted 0.03, focus 0.01, 6.0ms
# Speed: 3.0ms preprocess, 6.0ms inference, 1.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.98, distracted 0.02, focus 0.00, 0.0ms
# Speed: 0.0ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.96, distracted 0.03, focus 0.01, 8.5ms
# Speed: 0.0ms preprocess, 8.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.97, distracted 0.02, focus 0.01, 6.0ms
# Speed: 3.0ms preprocess, 6.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.97, distracted 0.02, focus 0.01, 0.0ms
# Speed: 0.0ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.96, distracted 0.03, focus 0.01, 6.5ms
# Speed: 2.5ms preprocess, 6.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.96, distracted 0.03, focus 0.02, 6.0ms
# Speed: 4.2ms preprocess, 6.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.96, distracted 0.02, focus 0.01, 0.0ms
# Speed: 3.9ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
# ¡ALERTA! El conductor ha estado cansado por más de 2 segundos consecutivos.
#
# 0: 128x128 focus 0.66, tired 0.29, distracted 0.05, 8.0ms
# Speed: 0.0ms preprocess, 8.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.84, tired 0.12, distracted 0.04, 8.3ms
# Speed: 3.2ms preprocess, 8.3ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.58, tired 0.36, distracted 0.06, 7.6ms
# Speed: 3.9ms preprocess, 7.6ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.53, tired 0.41, distracted 0.06, 6.2ms
# Speed: 2.9ms preprocess, 6.2ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.55, tired 0.37, distracted 0.08, 7.1ms
# Speed: 3.0ms preprocess, 7.1ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.49, focus 0.42, distracted 0.09, 0.0ms
# Speed: 2.5ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.56, focus 0.38, distracted 0.07, 8.5ms
# Speed: 0.0ms preprocess, 8.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.62, tired 0.29, distracted 0.09, 6.0ms
# Speed: 4.0ms preprocess, 6.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.41, focus 0.39, distracted 0.20, 0.0ms
# Speed: 2.0ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.52, tired 0.33, distracted 0.15, 9.0ms
# Speed: 0.0ms preprocess, 9.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.54, tired 0.28, distracted 0.18, 6.0ms
# Speed: 3.1ms preprocess, 6.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.55, tired 0.26, distracted 0.19, 0.0ms
# Speed: 0.0ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.46, tired 0.35, distracted 0.19, 9.5ms
# Speed: 0.0ms preprocess, 9.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.45, tired 0.38, distracted 0.16, 6.0ms
# Speed: 3.0ms preprocess, 6.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.64, focus 0.19, distracted 0.18, 0.0ms
# Speed: 2.5ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.71, distracted 0.20, focus 0.09, 8.5ms
# Speed: 0.0ms preprocess, 8.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.72, distracted 0.17, focus 0.10, 7.0ms
# Speed: 3.0ms preprocess, 7.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.69, distracted 0.21, focus 0.11, 0.0ms
# Speed: 2.0ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.75, distracted 0.21, focus 0.04, 9.5ms
# Speed: 0.0ms preprocess, 9.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.54, distracted 0.34, focus 0.13, 6.0ms
# Speed: 3.0ms preprocess, 6.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.62, distracted 0.35, focus 0.03, 0.0ms
# Speed: 2.0ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.52, tired 0.47, focus 0.01, 8.5ms
# ...
# Speed: 4.4ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.86, tired 0.12, focus 0.01, 3.5ms
# Speed: 4.5ms preprocess, 3.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.90, tired 0.08, focus 0.02, 6.1ms
# Speed: 1.0ms preprocess, 6.1ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.93, tired 0.06, focus 0.01, 0.0ms
# Speed: 0.0ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.83, tired 0.13, focus 0.03, 12.3ms
# Speed: 1.8ms preprocess, 12.3ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.80, tired 0.16, focus 0.04, 8.0ms
# Speed: 0.0ms preprocess, 8.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.77, tired 0.17, focus 0.07, 0.0ms
# Speed: 4.3ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.59, tired 0.27, focus 0.14, 0.0ms
# Speed: 0.0ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.56, focus 0.26, tired 0.17, 8.5ms
# Speed: 0.0ms preprocess, 8.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.69, tired 0.18, focus 0.12, 0.0ms
# Speed: 0.0ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.53, focus 0.25, tired 0.22, 1.0ms
# Speed: 5.3ms preprocess, 1.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.44, focus 0.31, tired 0.25, 10.2ms
# Speed: 5.5ms preprocess, 10.2ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.54, focus 0.24, tired 0.23, 5.7ms
# Speed: 3.1ms preprocess, 5.7ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.40, distracted 0.37, tired 0.23, 0.0ms
# Speed: 5.2ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.53, focus 0.32, tired 0.16, 6.0ms
# Speed: 0.0ms preprocess, 6.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.60, focus 0.24, tired 0.16, 0.0ms
# Speed: 4.1ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.49, tired 0.36, focus 0.15, 0.0ms
# Speed: 0.0ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.64, focus 0.22, tired 0.14, 9.5ms
# Speed: 0.9ms preprocess, 9.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.46, focus 0.39, tired 0.15, 12.1ms
# Speed: 2.6ms preprocess, 12.1ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.54, distracted 0.29, tired 0.16, 10.9ms
# Speed: 2.7ms preprocess, 10.9ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.48, distracted 0.38, tired 0.14, 9.4ms
# Speed: 0.0ms preprocess, 9.4ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.47, distracted 0.41, tired 0.11, 7.9ms
# Speed: 0.0ms preprocess, 7.9ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.52, distracted 0.40, tired 0.07, 8.7ms
# Speed: 0.0ms preprocess, 8.7ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.54, distracted 0.32, tired 0.14, 0.0ms
# Speed: 0.0ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.55, distracted 0.33, tired 0.12, 10.3ms
# Speed: 0.0ms preprocess, 10.3ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.55, distracted 0.33, tired 0.12, 0.0ms
# Speed: 1.3ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.42, focus 0.42, tired 0.16, 6.5ms
# Speed: 2.0ms preprocess, 6.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.57, distracted 0.24, tired 0.18, 4.6ms
# Speed: 1.0ms preprocess, 4.6ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.37, distracted 0.32, tired 0.31, 9.5ms
# Speed: 0.0ms preprocess, 9.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.39, distracted 0.34, tired 0.28, 0.0ms
# Speed: 0.0ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.69, distracted 0.24, tired 0.07, 11.6ms
# Speed: 0.0ms preprocess, 11.6ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.41, tired 0.33, distracted 0.26, 7.2ms
# Speed: 2.7ms preprocess, 7.2ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.46, distracted 0.28, tired 0.26, 9.6ms
# Speed: 0.0ms preprocess, 9.6ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.50, tired 0.37, distracted 0.13, 12.6ms
# Speed: 2.3ms preprocess, 12.6ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.67, tired 0.25, distracted 0.07, 8.8ms
# Speed: 5.7ms preprocess, 8.8ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.65, tired 0.25, distracted 0.09, 1.0ms
# Speed: 3.8ms preprocess, 1.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.84, distracted 0.12, tired 0.05, 10.6ms
# Speed: 0.0ms preprocess, 10.6ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.87, distracted 0.07, tired 0.05, 10.6ms
# Speed: 0.0ms preprocess, 10.6ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.87, distracted 0.07, tired 0.05, 6.0ms
# Speed: 1.0ms preprocess, 6.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.83, tired 0.10, distracted 0.07, 0.0ms
# Speed: 0.0ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.93, tired 0.06, distracted 0.01, 0.0ms
# Speed: 0.0ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.80, tired 0.18, distracted 0.02, 10.0ms
# Speed: 0.9ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.68, tired 0.28, distracted 0.04, 12.4ms
# Speed: 0.9ms preprocess, 12.4ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.79, tired 0.15, distracted 0.06, 0.0ms
# Speed: 0.0ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.90, tired 0.06, distracted 0.04, 9.0ms
# Speed: 0.0ms preprocess, 9.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.85, tired 0.11, distracted 0.03, 0.0ms
# Speed: 0.0ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.89, tired 0.09, distracted 0.02, 0.0ms
# Speed: 0.0ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.90, tired 0.08, distracted 0.02, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.84, tired 0.14, distracted 0.01, 12.5ms
# Speed: 2.9ms preprocess, 12.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.77, tired 0.21, distracted 0.02, 10.6ms
# Speed: 0.0ms preprocess, 10.6ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.62, tired 0.36, distracted 0.02, 10.7ms
# Speed: 0.0ms preprocess, 10.7ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.62, tired 0.36, distracted 0.02, 0.0ms
# Speed: 0.0ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.58, focus 0.40, distracted 0.02, 7.0ms
# Speed: 0.0ms preprocess, 7.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.53, tired 0.45, distracted 0.02, 11.5ms
# Speed: 0.0ms preprocess, 11.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.73, tired 0.25, distracted 0.02, 0.0ms
# Speed: 1.4ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.74, tired 0.23, distracted 0.03, 10.9ms
# Speed: 0.0ms preprocess, 10.9ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.89, tired 0.08, distracted 0.03, 10.2ms
# Speed: 0.0ms preprocess, 10.2ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.94, tired 0.05, distracted 0.02, 8.4ms
# Speed: 0.0ms preprocess, 8.4ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.85, tired 0.12, distracted 0.03, 7.6ms
# Speed: 0.0ms preprocess, 7.6ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.74, tired 0.22, distracted 0.04, 1.0ms
# Speed: 5.0ms preprocess, 1.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.92, tired 0.05, distracted 0.03, 9.2ms
# Speed: 0.0ms preprocess, 9.2ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.91, tired 0.05, distracted 0.04, 10.6ms
# Speed: 0.0ms preprocess, 10.6ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.95, tired 0.03, distracted 0.02, 7.1ms
# Speed: 4.0ms preprocess, 7.1ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.95, tired 0.03, distracted 0.02, 0.0ms
# Speed: 0.0ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.96, tired 0.02, distracted 0.01, 0.0ms
# Speed: 0.0ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.92, tired 0.05, distracted 0.03, 10.5ms
# Speed: 0.5ms preprocess, 10.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.94, tired 0.04, distracted 0.03, 7.0ms
# Speed: 3.1ms preprocess, 7.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.93, tired 0.05, distracted 0.02, 0.0ms
# Speed: 0.0ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.96, distracted 0.02, tired 0.01, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.96, tired 0.02, distracted 0.02, 7.0ms
# Speed: 3.0ms preprocess, 7.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.87, distracted 0.07, tired 0.06, 8.5ms
# Speed: 0.0ms preprocess, 8.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.86, tired 0.10, distracted 0.05, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.71, distracted 0.21, tired 0.08, 9.9ms
# Speed: 4.4ms preprocess, 9.9ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.71, tired 0.23, distracted 0.06, 11.7ms
# Speed: 4.9ms preprocess, 11.7ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.77, tired 0.16, distracted 0.07, 8.2ms
# Speed: 3.7ms preprocess, 8.2ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.64, tired 0.26, distracted 0.10, 7.8ms
# Speed: 3.5ms preprocess, 7.8ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.64, tired 0.26, distracted 0.10, 8.0ms
# Speed: 0.0ms preprocess, 8.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.72, tired 0.21, distracted 0.07, 11.0ms
# Speed: 0.0ms preprocess, 11.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.54, tired 0.40, distracted 0.06, 7.0ms
# Speed: 3.5ms preprocess, 7.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.68, tired 0.26, distracted 0.06, 6.0ms
# Speed: 0.9ms preprocess, 6.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.65, tired 0.31, distracted 0.04, 10.7ms
# Speed: 0.0ms preprocess, 10.7ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.62, tired 0.34, distracted 0.05, 5.6ms
# Speed: 0.0ms preprocess, 5.6ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.55, tired 0.39, distracted 0.06, 6.0ms
# Speed: 3.2ms preprocess, 6.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.65, focus 0.31, distracted 0.04, 8.6ms
# Speed: 0.0ms preprocess, 8.6ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.71, focus 0.18, distracted 0.11, 10.4ms
# Speed: 0.0ms preprocess, 10.4ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.42, tired 0.42, distracted 0.16, 7.0ms
# Speed: 4.0ms preprocess, 7.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.56, focus 0.36, distracted 0.08, 11.0ms
# Speed: 0.0ms preprocess, 11.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.72, focus 0.19, distracted 0.09, 6.0ms
# Speed: 3.0ms preprocess, 6.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.75, focus 0.20, distracted 0.05, 0.0ms
# Speed: 0.0ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.75, focus 0.20, distracted 0.05, 8.5ms
# Speed: 0.0ms preprocess, 8.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.79, focus 0.17, distracted 0.04, 12.0ms
# Speed: 2.9ms preprocess, 12.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.66, focus 0.26, distracted 0.08, 5.5ms
# Speed: 4.9ms preprocess, 5.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.58, focus 0.34, distracted 0.08, 6.0ms
# Speed: 3.0ms preprocess, 6.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.54, tired 0.38, distracted 0.08, 8.7ms
# Speed: 0.0ms preprocess, 8.7ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.47, focus 0.46, distracted 0.07, 6.5ms
# Speed: 0.0ms preprocess, 6.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.49, focus 0.41, distracted 0.10, 0.0ms
# Speed: 4.8ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.88, tired 0.08, distracted 0.04, 8.1ms
# Speed: 4.1ms preprocess, 8.1ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.87, tired 0.09, distracted 0.04, 0.0ms
# Speed: 1.9ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.85, tired 0.10, distracted 0.04, 0.0ms
# Speed: 1.0ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.86, tired 0.10, distracted 0.03, 9.5ms
# Speed: 0.5ms preprocess, 9.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.95, tired 0.04, distracted 0.02, 0.0ms
# Speed: 0.0ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.96, tired 0.03, distracted 0.01, 12.3ms
# Speed: 0.0ms preprocess, 12.3ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.96, tired 0.03, distracted 0.01, 9.5ms
# Speed: 1.3ms preprocess, 9.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)

# %%
import cv2
from ultralytics import YOLO

model = YOLO('model/model_3.pt')
# Capturar video de la cámara
cap = cv2.VideoCapture(0)

while True:
    ret, frame = cap.read()
    if not ret:
        break

    # Procesar el frame con YOLO
    results = model(frame)

    # Obtener las detecciones
    #detections = results.names[results.probs.top1]
    detections = results[0].names[results[0].probs.top1]

    cv2.putText(frame, detections, (50, 50), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2)

    cv2.imshow('Detección de Fatiga', frame)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 128x128 focus 0.73, distracted 0.14, tired 0.14, 7.0ms
# Speed: 4.9ms preprocess, 7.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.83, tired 0.09, distracted 0.08, 10.5ms
# Speed: 3.0ms preprocess, 10.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.77, distracted 0.12, tired 0.11, 10.6ms
# Speed: 3.3ms preprocess, 10.6ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.66, tired 0.21, distracted 0.13, 6.2ms
# Speed: 4.0ms preprocess, 6.2ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.73, tired 0.15, distracted 0.12, 6.9ms
# Speed: 3.5ms preprocess, 6.9ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.76, tired 0.14, distracted 0.10, 6.6ms
# Speed: 3.5ms preprocess, 6.6ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.71, tired 0.18, distracted 0.10, 10.6ms
# Speed: 5.5ms preprocess, 10.6ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.66, tired 0.19, distracted 0.15, 10.8ms
# Speed: 3.0ms preprocess, 10.8ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.70, distracted 0.17, tired 0.13, 11.5ms
# Speed: 3.0ms preprocess, 11.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.89, distracted 0.06, tired 0.05, 9.0ms
# Speed: 4.0ms preprocess, 9.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.76, tired 0.13, distracted 0.11, 6.7ms
# Speed: 3.0ms preprocess, 6.7ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.71, tired 0.15, distracted 0.13, 7.5ms
# Speed: 6.0ms preprocess, 7.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.83, tired 0.10, distracted 0.07, 7.0ms
# Speed: 5.0ms preprocess, 7.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.87, tired 0.07, distracted 0.06, 8.0ms
# Speed: 5.0ms preprocess, 8.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.85, tired 0.09, distracted 0.06, 9.5ms
# Speed: 3.5ms preprocess, 9.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.69, tired 0.18, distracted 0.13, 11.5ms
# Speed: 3.5ms preprocess, 11.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.83, distracted 0.09, tired 0.07, 9.5ms
# Speed: 3.0ms preprocess, 9.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.82, tired 0.09, distracted 0.09, 9.4ms
# Speed: 3.2ms preprocess, 9.4ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.79, tired 0.11, distracted 0.10, 7.5ms
# Speed: 3.6ms preprocess, 7.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.85, tired 0.08, distracted 0.07, 6.5ms
# Speed: 4.0ms preprocess, 6.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.83, tired 0.09, distracted 0.08, 7.2ms
# Speed: 5.5ms preprocess, 7.2ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.90, distracted 0.05, tired 0.04, 10.5ms
# Speed: 3.0ms preprocess, 10.5ms inference, 1.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.93, tired 0.04, distracted 0.03, 11.5ms
# Speed: 3.0ms preprocess, 11.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.96, tired 0.03, distracted 0.01, 10.5ms
# Speed: 3.5ms preprocess, 10.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.99, distracted 0.01, tired 0.01, 9.7ms
# Speed: 3.0ms preprocess, 9.7ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.98, distracted 0.01, tired 0.01, 10.1ms
# Speed: 2.9ms preprocess, 10.1ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.99, tired 0.01, distracted 0.01, 7.5ms
# Speed: 4.0ms preprocess, 7.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.98, tired 0.01, distracted 0.01, 6.5ms
# Speed: 3.1ms preprocess, 6.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.97, tired 0.01, distracted 0.01, 7.5ms
# Speed: 3.0ms preprocess, 7.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.99, distracted 0.01, tired 0.01, 7.0ms
# Speed: 5.5ms preprocess, 7.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.99, distracted 0.01, tired 0.01, 7.2ms
# Speed: 7.2ms preprocess, 7.2ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.99, distracted 0.01, tired 0.00, 6.5ms
# Speed: 4.0ms preprocess, 6.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.98, distracted 0.01, tired 0.01, 6.5ms
# Speed: 3.5ms preprocess, 6.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.99, distracted 0.01, tired 0.00, 8.1ms
# Speed: 4.6ms preprocess, 8.1ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.99, distracted 0.00, tired 0.00, 9.5ms
# Speed: 3.5ms preprocess, 9.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.99, tired 0.00, distracted 0.00, 9.9ms
# Speed: 3.5ms preprocess, 9.9ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 1.00, distracted 0.00, tired 0.00, 8.8ms
# Speed: 3.0ms preprocess, 8.8ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 1.00, tired 0.00, distracted 0.00, 10.5ms
# Speed: 3.0ms preprocess, 10.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.99, tired 0.00, distracted 0.00, 9.5ms
# Speed: 3.5ms preprocess, 9.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 1.00, tired 0.00, distracted 0.00, 6.2ms
# Speed: 3.5ms preprocess, 6.2ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 1.00, tired 0.00, distracted 0.00, 6.5ms
# Speed: 3.0ms preprocess, 6.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.99, tired 0.01, distracted 0.00, 7.1ms
# Speed: 4.0ms preprocess, 7.1ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.98, tired 0.02, distracted 0.00, 7.0ms
# Speed: 6.0ms preprocess, 7.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.99, tired 0.01, distracted 0.00, 7.5ms
# Speed: 4.5ms preprocess, 7.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.98, tired 0.01, distracted 0.00, 8.9ms
# Speed: 4.0ms preprocess, 8.9ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.97, tired 0.03, distracted 0.00, 9.5ms
# Speed: 3.0ms preprocess, 9.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.99, tired 0.01, distracted 0.00, 8.5ms
# Speed: 3.5ms preprocess, 8.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.99, tired 0.01, distracted 0.00, 9.5ms
# Speed: 3.0ms preprocess, 9.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.99, tired 0.01, distracted 0.00, 8.5ms
# Speed: 3.0ms preprocess, 8.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.98, tired 0.01, distracted 0.00, 9.5ms
# Speed: 3.0ms preprocess, 9.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.99, tired 0.00, distracted 0.00, 8.7ms
# Speed: 3.0ms preprocess, 8.7ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.99, tired 0.01, distracted 0.00, 8.0ms
# Speed: 4.0ms preprocess, 8.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.99, tired 0.00, distracted 0.00, 6.5ms
# Speed: 3.0ms preprocess, 6.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.98, tired 0.01, distracted 0.01, 6.9ms
# Speed: 2.5ms preprocess, 6.9ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.93, tired 0.05, distracted 0.02, 6.0ms
# Speed: 5.5ms preprocess, 6.0ms inference, 1.5ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.89, tired 0.09, distracted 0.02, 8.5ms
# Speed: 5.0ms preprocess, 8.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.77, tired 0.21, distracted 0.03, 10.5ms
# Speed: 4.0ms preprocess, 10.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.90, distracted 0.05, tired 0.05, 10.9ms
# Speed: 3.0ms preprocess, 10.9ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.95, distracted 0.03, tired 0.02, 11.1ms
# Speed: 4.0ms preprocess, 11.1ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.95, distracted 0.04, tired 0.01, 10.5ms
# Speed: 3.3ms preprocess, 10.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.86, distracted 0.10, tired 0.04, 8.5ms
# Speed: 3.5ms preprocess, 8.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.91, distracted 0.06, tired 0.03, 11.0ms
# Speed: 3.2ms preprocess, 11.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.94, distracted 0.04, tired 0.02, 8.6ms
# Speed: 2.0ms preprocess, 8.6ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.86, distracted 0.08, tired 0.06, 7.8ms
# Speed: 3.3ms preprocess, 7.8ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.88, distracted 0.09, tired 0.03, 6.5ms
# Speed: 3.3ms preprocess, 6.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.79, distracted 0.17, tired 0.04, 7.5ms
# Speed: 3.5ms preprocess, 7.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.74, distracted 0.23, tired 0.03, 6.8ms
# Speed: 3.0ms preprocess, 6.8ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.63, distracted 0.33, tired 0.03, 7.7ms
# Speed: 3.5ms preprocess, 7.7ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.60, distracted 0.37, tired 0.03, 9.3ms
# Speed: 3.0ms preprocess, 9.3ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.62, distracted 0.34, tired 0.04, 9.5ms
# Speed: 3.0ms preprocess, 9.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.52, distracted 0.43, tired 0.06, 9.9ms
# Speed: 3.5ms preprocess, 9.9ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.60, distracted 0.28, tired 0.12, 9.5ms
# Speed: 3.5ms preprocess, 9.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.45, distracted 0.37, tired 0.18, 8.5ms
# Speed: 3.5ms preprocess, 8.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.44, focus 0.39, tired 0.17, 8.1ms
# Speed: 3.5ms preprocess, 8.1ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.37, distracted 0.35, focus 0.28, 9.5ms
# Speed: 3.0ms preprocess, 9.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.38, distracted 0.34, tired 0.29, 12.5ms
# Speed: 3.5ms preprocess, 12.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.48, distracted 0.31, focus 0.21, 11.0ms
# Speed: 4.0ms preprocess, 11.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.36, distracted 0.34, tired 0.29, 10.0ms
# Speed: 3.5ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.48, distracted 0.27, focus 0.25, 7.0ms
# Speed: 4.5ms preprocess, 7.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.41, tired 0.37, focus 0.22, 7.5ms
# Speed: 5.0ms preprocess, 7.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.39, distracted 0.35, focus 0.26, 6.5ms
# Speed: 4.6ms preprocess, 6.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.46, distracted 0.33, focus 0.21, 7.0ms
# Speed: 4.9ms preprocess, 7.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.39, tired 0.32, focus 0.28, 7.5ms
# Speed: 4.5ms preprocess, 7.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.46, tired 0.35, focus 0.19, 10.0ms
# Speed: 3.0ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.42, distracted 0.40, focus 0.18, 8.6ms
# Speed: 3.0ms preprocess, 8.6ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.52, distracted 0.29, focus 0.19, 8.5ms
# Speed: 3.0ms preprocess, 8.5ms inference, 1.3ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.44, distracted 0.41, focus 0.15, 12.1ms
# Speed: 3.0ms preprocess, 12.1ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.39, distracted 0.38, focus 0.23, 9.9ms
# Speed: 3.5ms preprocess, 9.9ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.43, tired 0.34, focus 0.23, 7.2ms
# Speed: 3.2ms preprocess, 7.2ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.46, tired 0.32, focus 0.21, 7.5ms
# Speed: 4.0ms preprocess, 7.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.40, distracted 0.37, focus 0.23, 7.1ms
# Speed: 6.0ms preprocess, 7.1ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.46, tired 0.31, focus 0.23, 7.8ms
# Speed: 4.5ms preprocess, 7.8ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.50, tired 0.30, focus 0.21, 9.5ms
# Speed: 3.0ms preprocess, 9.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.45, focus 0.29, tired 0.26, 11.2ms
# Speed: 3.4ms preprocess, 11.2ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.60, tired 0.21, focus 0.19, 10.0ms
# Speed: 3.0ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.67, distracted 0.21, focus 0.11, 7.0ms
# Speed: 5.0ms preprocess, 7.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.65, distracted 0.23, focus 0.13, 7.2ms
# Speed: 5.0ms preprocess, 7.2ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.47, distracted 0.30, focus 0.22, 9.9ms
# Speed: 3.0ms preprocess, 9.9ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.65, distracted 0.26, focus 0.10, 9.2ms
# Speed: 3.5ms preprocess, 9.2ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.56, distracted 0.25, focus 0.19, 8.5ms
# Speed: 3.0ms preprocess, 8.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.67, distracted 0.18, focus 0.15, 8.8ms
# Speed: 4.0ms preprocess, 8.8ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.60, distracted 0.28, focus 0.12, 6.5ms
# Speed: 4.0ms preprocess, 6.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.65, distracted 0.20, focus 0.15, 6.5ms
# Speed: 4.0ms preprocess, 6.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.62, distracted 0.23, focus 0.15, 7.8ms
# Speed: 4.0ms preprocess, 7.8ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.60, distracted 0.23, focus 0.16, 10.5ms
# Speed: 3.0ms preprocess, 10.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.74, distracted 0.16, focus 0.10, 8.7ms
# Speed: 3.0ms preprocess, 8.7ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.72, distracted 0.19, focus 0.09, 8.0ms
# Speed: 3.8ms preprocess, 8.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.68, distracted 0.22, focus 0.10, 9.5ms
# Speed: 3.5ms preprocess, 9.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.62, distracted 0.26, focus 0.12, 9.5ms
# Speed: 3.5ms preprocess, 9.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.67, distracted 0.23, focus 0.11, 9.0ms
# Speed: 3.5ms preprocess, 9.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.61, distracted 0.25, focus 0.14, 9.0ms
# Speed: 3.6ms preprocess, 9.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.65, distracted 0.25, focus 0.11, 10.5ms
# Speed: 3.4ms preprocess, 10.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.56, distracted 0.30, focus 0.14, 9.0ms
# Speed: 3.0ms preprocess, 9.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.61, distracted 0.26, focus 0.13, 8.7ms
# Speed: 4.0ms preprocess, 8.7ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.57, distracted 0.32, focus 0.11, 12.0ms
# Speed: 4.5ms preprocess, 12.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.66, distracted 0.24, focus 0.10, 9.0ms
# Speed: 3.5ms preprocess, 9.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.47, distracted 0.39, focus 0.14, 10.0ms
# Speed: 4.2ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.52, distracted 0.36, focus 0.12, 7.0ms
# Speed: 4.8ms preprocess, 7.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.54, distracted 0.31, focus 0.15, 10.5ms
# Speed: 2.9ms preprocess, 10.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.54, distracted 0.34, focus 0.13, 9.5ms
# Speed: 4.5ms preprocess, 9.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.57, distracted 0.28, focus 0.15, 8.8ms
# Speed: 4.4ms preprocess, 8.8ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.53, distracted 0.29, focus 0.17, 8.8ms
# Speed: 3.0ms preprocess, 8.8ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.49, distracted 0.33, focus 0.18, 9.5ms
# Speed: 3.0ms preprocess, 9.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.53, distracted 0.31, focus 0.15, 7.0ms
# Speed: 3.5ms preprocess, 7.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.47, distracted 0.32, focus 0.20, 7.5ms
# Speed: 3.0ms preprocess, 7.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.66, distracted 0.23, focus 0.11, 6.7ms
# Speed: 4.0ms preprocess, 6.7ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.59, distracted 0.26, focus 0.15, 7.5ms
# Speed: 3.0ms preprocess, 7.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.60, distracted 0.27, focus 0.13, 7.5ms
# Speed: 5.1ms preprocess, 7.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.45, tired 0.37, focus 0.17, 8.0ms
# Speed: 4.5ms preprocess, 8.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.42, tired 0.41, focus 0.17, 9.5ms
# Speed: 3.0ms preprocess, 9.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.50, tired 0.33, focus 0.17, 9.2ms
# Speed: 3.4ms preprocess, 9.2ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.59, tired 0.31, focus 0.11, 9.5ms
# Speed: 3.5ms preprocess, 9.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.57, tired 0.28, focus 0.15, 7.5ms
# Speed: 5.0ms preprocess, 7.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.54, tired 0.26, focus 0.21, 7.5ms
# Speed: 3.0ms preprocess, 7.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.45, tired 0.29, focus 0.25, 9.5ms
# Speed: 2.2ms preprocess, 9.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.35, distracted 0.33, focus 0.32, 8.5ms
# Speed: 3.5ms preprocess, 8.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.38, distracted 0.32, focus 0.30, 6.5ms
# Speed: 3.0ms preprocess, 6.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.41, distracted 0.30, focus 0.29, 6.5ms
# Speed: 3.0ms preprocess, 6.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.39, focus 0.36, tired 0.25, 10.5ms
# Speed: 4.0ms preprocess, 10.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.35, tired 0.35, focus 0.29, 10.0ms
# Speed: 5.5ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.41, distracted 0.41, tired 0.18, 9.6ms
# Speed: 3.5ms preprocess, 9.6ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.67, distracted 0.24, tired 0.09, 8.4ms
# Speed: 3.3ms preprocess, 8.4ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.64, distracted 0.31, tired 0.05, 10.1ms
# Speed: 2.5ms preprocess, 10.1ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.79, distracted 0.14, tired 0.07, 8.5ms
# Speed: 3.5ms preprocess, 8.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.92, distracted 0.06, tired 0.02, 8.5ms
# Speed: 3.5ms preprocess, 8.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.96, tired 0.03, distracted 0.02, 8.1ms
# Speed: 4.0ms preprocess, 8.1ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.99, tired 0.01, distracted 0.00, 7.9ms
# Speed: 3.5ms preprocess, 7.9ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.99, tired 0.01, distracted 0.00, 9.6ms
# Speed: 3.0ms preprocess, 9.6ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.99, tired 0.01, distracted 0.00, 9.1ms
# Speed: 3.0ms preprocess, 9.1ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 1.00, tired 0.00, distracted 0.00, 6.5ms
# Speed: 4.0ms preprocess, 6.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 1.00, tired 0.00, distracted 0.00, 6.5ms
# Speed: 3.2ms preprocess, 6.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 1.00, tired 0.00, distracted 0.00, 6.4ms
# Speed: 5.0ms preprocess, 6.4ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 1.00, tired 0.00, distracted 0.00, 8.0ms
# Speed: 4.6ms preprocess, 8.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 1.00, tired 0.00, distracted 0.00, 9.1ms
# Speed: 3.5ms preprocess, 9.1ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 1.00, tired 0.00, distracted 0.00, 9.6ms
# Speed: 3.1ms preprocess, 9.6ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 1.00, tired 0.00, distracted 0.00, 8.4ms
# Speed: 3.5ms preprocess, 8.4ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 1.00, tired 0.00, distracted 0.00, 9.5ms
# Speed: 4.4ms preprocess, 9.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 1.00, tired 0.00, distracted 0.00, 8.8ms
# Speed: 4.5ms preprocess, 8.8ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 1.00, tired 0.00, distracted 0.00, 8.5ms
# Speed: 3.1ms preprocess, 8.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 1.00, tired 0.00, distracted 0.00, 6.8ms
# Speed: 3.4ms preprocess, 6.8ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 1.00, tired 0.00, distracted 0.00, 6.5ms
# Speed: 3.2ms preprocess, 6.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 1.00, tired 0.00, distracted 0.00, 7.8ms
# Speed: 3.2ms preprocess, 7.8ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.99, tired 0.01, distracted 0.00, 5.5ms
# Speed: 4.0ms preprocess, 5.5ms inference, 1.4ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.99, tired 0.01, distracted 0.00, 7.0ms
# Speed: 3.5ms preprocess, 7.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 1.00, tired 0.00, distracted 0.00, 6.5ms
# Speed: 4.1ms preprocess, 6.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.99, tired 0.00, distracted 0.00, 7.9ms
# Speed: 4.5ms preprocess, 7.9ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.99, tired 0.01, distracted 0.00, 10.1ms
# Speed: 3.5ms preprocess, 10.1ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 1.00, tired 0.00, distracted 0.00, 8.5ms
# Speed: 3.5ms preprocess, 8.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 1.00, distracted 0.00, tired 0.00, 9.5ms
# Speed: 2.5ms preprocess, 9.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 1.00, distracted 0.00, tired 0.00, 9.2ms
# Speed: 3.4ms preprocess, 9.2ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.98, distracted 0.01, tired 0.01, 7.0ms
# Speed: 3.5ms preprocess, 7.0ms inference, 1.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.99, distracted 0.00, tired 0.00, 7.0ms
# Speed: 3.5ms preprocess, 7.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 1.00, tired 0.00, distracted 0.00, 11.0ms
# Speed: 4.1ms preprocess, 11.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 1.00, distracted 0.00, tired 0.00, 9.5ms
# Speed: 4.0ms preprocess, 9.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 1.00, distracted 0.00, tired 0.00, 6.5ms
# Speed: 3.0ms preprocess, 6.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.99, distracted 0.00, tired 0.00, 7.5ms
# Speed: 3.5ms preprocess, 7.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 1.00, distracted 0.00, tired 0.00, 7.1ms
# Speed: 6.0ms preprocess, 7.1ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.99, distracted 0.00, tired 0.00, 9.3ms
# Speed: 4.4ms preprocess, 9.3ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.99, distracted 0.01, tired 0.00, 13.0ms
# Speed: 3.0ms preprocess, 13.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.97, tired 0.02, distracted 0.02, 10.5ms
# Speed: 4.2ms preprocess, 10.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.97, tired 0.02, distracted 0.01, 10.0ms
# Speed: 3.5ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.99, distracted 0.01, tired 0.01, 8.4ms
# Speed: 3.2ms preprocess, 8.4ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.98, tired 0.01, distracted 0.01, 7.5ms
# Speed: 3.4ms preprocess, 7.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.99, distracted 0.01, tired 0.01, 7.0ms
# Speed: 3.6ms preprocess, 7.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.99, tired 0.01, distracted 0.00, 6.5ms
# Speed: 3.5ms preprocess, 6.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.99, distracted 0.00, tired 0.00, 8.5ms
# Speed: 3.4ms preprocess, 8.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.99, tired 0.01, distracted 0.01, 6.5ms
# Speed: 3.4ms preprocess, 6.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.99, tired 0.00, distracted 0.00, 6.5ms
# Speed: 3.5ms preprocess, 6.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.99, tired 0.01, distracted 0.00, 6.5ms
# Speed: 3.7ms preprocess, 6.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 1.00, distracted 0.00, tired 0.00, 6.5ms
# Speed: 5.0ms preprocess, 6.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 1.00, distracted 0.00, tired 0.00, 9.5ms
# Speed: 3.0ms preprocess, 9.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.99, distracted 0.00, tired 0.00, 9.7ms
# Speed: 3.0ms preprocess, 9.7ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.99, tired 0.01, distracted 0.00, 11.0ms
# Speed: 3.0ms preprocess, 11.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.99, tired 0.01, distracted 0.00, 8.5ms
# Speed: 3.0ms preprocess, 8.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.99, tired 0.01, distracted 0.00, 7.5ms
# Speed: 5.0ms preprocess, 7.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.99, tired 0.00, distracted 0.00, 10.4ms
# Speed: 3.0ms preprocess, 10.4ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.98, tired 0.02, distracted 0.01, 9.5ms
# Speed: 3.1ms preprocess, 9.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.98, tired 0.01, distracted 0.01, 9.5ms
# Speed: 3.0ms preprocess, 9.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.91, tired 0.08, distracted 0.01, 10.5ms
# Speed: 3.0ms preprocess, 10.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.88, tired 0.10, distracted 0.02, 8.0ms
# Speed: 3.0ms preprocess, 8.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.91, tired 0.07, distracted 0.02, 6.9ms
# Speed: 3.5ms preprocess, 6.9ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.92, tired 0.05, distracted 0.03, 8.0ms
# Speed: 4.9ms preprocess, 8.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.85, distracted 0.11, tired 0.04, 10.0ms
# Speed: 3.5ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.91, distracted 0.06, tired 0.02, 10.5ms
# Speed: 3.5ms preprocess, 10.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.80, distracted 0.11, tired 0.08, 10.5ms
# Speed: 2.5ms preprocess, 10.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.65, focus 0.23, distracted 0.12, 12.0ms
# Speed: 3.0ms preprocess, 12.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.65, focus 0.23, distracted 0.12, 6.5ms
# Speed: 3.7ms preprocess, 6.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.67, focus 0.23, distracted 0.10, 6.5ms
# Speed: 4.5ms preprocess, 6.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.74, focus 0.16, distracted 0.11, 7.0ms
# Speed: 4.6ms preprocess, 7.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.59, distracted 0.22, focus 0.19, 7.1ms
# Speed: 4.7ms preprocess, 7.1ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.42, focus 0.33, distracted 0.25, 8.5ms
# Speed: 3.5ms preprocess, 8.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.40, distracted 0.36, focus 0.24, 9.6ms
# Speed: 3.5ms preprocess, 9.6ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.43, tired 0.35, focus 0.22, 10.2ms
# Speed: 4.0ms preprocess, 10.2ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.41, distracted 0.32, focus 0.27, 7.5ms
# Speed: 4.0ms preprocess, 7.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.36, tired 0.32, focus 0.32, 7.8ms
# Speed: 3.4ms preprocess, 7.8ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.41, tired 0.30, focus 0.29, 6.5ms
# Speed: 4.6ms preprocess, 6.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.56, distracted 0.29, focus 0.16, 8.2ms
# Speed: 4.8ms preprocess, 8.2ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.46, distracted 0.38, focus 0.17, 7.9ms
# Speed: 3.0ms preprocess, 7.9ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.50, distracted 0.36, focus 0.14, 7.3ms
# Speed: 3.5ms preprocess, 7.3ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.50, distracted 0.36, focus 0.14, 10.2ms
# Speed: 3.0ms preprocess, 10.2ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.54, distracted 0.36, focus 0.10, 7.5ms
# Speed: 3.3ms preprocess, 7.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.53, distracted 0.39, focus 0.08, 7.5ms
# Speed: 4.0ms preprocess, 7.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.47, distracted 0.46, focus 0.07, 9.5ms
# Speed: 3.2ms preprocess, 9.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.50, distracted 0.43, focus 0.07, 9.5ms
# Speed: 3.0ms preprocess, 9.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.47, distracted 0.46, focus 0.07, 9.3ms
# Speed: 3.0ms preprocess, 9.3ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.47, distracted 0.46, focus 0.07, 7.0ms
# Speed: 4.2ms preprocess, 7.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.54, distracted 0.37, focus 0.09, 7.5ms
# Speed: 3.9ms preprocess, 7.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.48, distracted 0.43, focus 0.10, 7.0ms
# Speed: 5.1ms preprocess, 7.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.45, distracted 0.44, focus 0.10, 7.9ms
# Speed: 4.3ms preprocess, 7.9ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.56, distracted 0.36, focus 0.09, 7.5ms
# Speed: 3.5ms preprocess, 7.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.63, distracted 0.30, focus 0.07, 7.5ms
# Speed: 3.0ms preprocess, 7.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.60, distracted 0.32, focus 0.08, 9.1ms
# Speed: 3.0ms preprocess, 9.1ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.60, distracted 0.32, focus 0.08, 9.5ms
# Speed: 4.4ms preprocess, 9.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.58, distracted 0.33, focus 0.08, 8.9ms
# Speed: 4.4ms preprocess, 8.9ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.55, distracted 0.39, focus 0.06, 10.9ms
# Speed: 5.0ms preprocess, 10.9ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.59, distracted 0.34, focus 0.08, 11.0ms
# Speed: 5.0ms preprocess, 11.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.51, distracted 0.40, focus 0.09, 11.7ms
# Speed: 4.7ms preprocess, 11.7ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.50, distracted 0.42, focus 0.08, 11.0ms
# Speed: 3.9ms preprocess, 11.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.64, distracted 0.30, focus 0.06, 11.5ms
# Speed: 3.9ms preprocess, 11.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.57, distracted 0.35, focus 0.08, 12.4ms
# Speed: 4.3ms preprocess, 12.4ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.57, distracted 0.36, focus 0.07, 9.7ms
# Speed: 3.7ms preprocess, 9.7ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.51, distracted 0.42, focus 0.07, 11.3ms
# Speed: 4.0ms preprocess, 11.3ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.58, distracted 0.34, focus 0.08, 9.5ms
# Speed: 4.7ms preprocess, 9.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.57, distracted 0.35, focus 0.08, 11.0ms
# Speed: 4.5ms preprocess, 11.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.57, distracted 0.35, focus 0.08, 11.5ms
# Speed: 4.7ms preprocess, 11.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.57, distracted 0.35, focus 0.08, 11.3ms
# Speed: 3.7ms preprocess, 11.3ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.54, distracted 0.38, focus 0.08, 6.5ms
# Speed: 4.4ms preprocess, 6.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.51, distracted 0.40, focus 0.08, 9.5ms
# Speed: 4.0ms preprocess, 9.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.46, distracted 0.43, focus 0.11, 8.8ms
# Speed: 4.2ms preprocess, 8.8ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.53, tired 0.35, focus 0.12, 8.8ms
# Speed: 6.2ms preprocess, 8.8ms inference, 1.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.47, tired 0.38, focus 0.16, 11.8ms
# Speed: 4.5ms preprocess, 11.8ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.50, tired 0.28, focus 0.22, 11.2ms
# Speed: 4.4ms preprocess, 11.2ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.45, tired 0.36, focus 0.19, 10.9ms
# Speed: 5.0ms preprocess, 10.9ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.38, tired 0.37, focus 0.24, 12.9ms
# Speed: 3.8ms preprocess, 12.9ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.49, focus 0.28, distracted 0.22, 10.5ms
# Speed: 5.5ms preprocess, 10.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.64, focus 0.21, distracted 0.16, 12.4ms
# Speed: 3.6ms preprocess, 12.4ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.57, focus 0.29, distracted 0.13, 11.1ms
# Speed: 4.0ms preprocess, 11.1ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.57, focus 0.29, distracted 0.13, 12.5ms
# Speed: 4.2ms preprocess, 12.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.63, focus 0.30, distracted 0.06, 11.5ms
# Speed: 4.2ms preprocess, 11.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.89, focus 0.07, distracted 0.04, 12.8ms
# Speed: 4.5ms preprocess, 12.8ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.90, focus 0.07, distracted 0.03, 9.7ms
# Speed: 5.0ms preprocess, 9.7ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.55, focus 0.40, distracted 0.05, 11.0ms
# Speed: 6.4ms preprocess, 11.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.73, tired 0.24, distracted 0.03, 11.8ms
# Speed: 4.0ms preprocess, 11.8ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.87, tired 0.11, distracted 0.01, 9.0ms
# Speed: 4.4ms preprocess, 9.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.96, tired 0.03, distracted 0.02, 12.5ms
# Speed: 4.0ms preprocess, 12.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.90, tired 0.09, distracted 0.01, 12.3ms
# Speed: 4.5ms preprocess, 12.3ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.95, tired 0.04, distracted 0.01, 10.5ms
# Speed: 5.5ms preprocess, 10.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.97, tired 0.02, distracted 0.01, 12.3ms
# Speed: 4.0ms preprocess, 12.3ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.98, tired 0.01, distracted 0.01, 10.8ms
# Speed: 5.1ms preprocess, 10.8ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.97, tired 0.02, distracted 0.01, 10.6ms
# Speed: 6.6ms preprocess, 10.6ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.97, tired 0.02, distracted 0.01, 10.5ms
# Speed: 4.3ms preprocess, 10.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.99, tired 0.01, distracted 0.00, 10.5ms
# Speed: 4.3ms preprocess, 10.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.99, tired 0.01, distracted 0.00, 10.0ms
# Speed: 6.4ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.99, tired 0.01, distracted 0.00, 12.5ms
# Speed: 4.8ms preprocess, 12.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.99, tired 0.01, distracted 0.00, 26.8ms
# Speed: 6.6ms preprocess, 26.8ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.98, tired 0.02, distracted 0.01, 14.4ms
# Speed: 4.4ms preprocess, 14.4ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.98, tired 0.01, distracted 0.00, 12.6ms
# Speed: 4.1ms preprocess, 12.6ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.90, tired 0.07, distracted 0.03, 7.5ms
# Speed: 4.0ms preprocess, 7.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.87, tired 0.09, distracted 0.04, 8.5ms
# Speed: 3.5ms preprocess, 8.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.90, tired 0.07, distracted 0.03, 8.6ms
# Speed: 4.5ms preprocess, 8.6ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.91, tired 0.07, distracted 0.02, 7.5ms
# Speed: 4.5ms preprocess, 7.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.74, tired 0.22, distracted 0.04, 6.9ms
# Speed: 4.0ms preprocess, 6.9ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.62, tired 0.31, distracted 0.06, 7.7ms
# Speed: 4.0ms preprocess, 7.7ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.62, tired 0.31, distracted 0.06, 8.7ms
# Speed: 4.0ms preprocess, 8.7ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.49, tired 0.44, distracted 0.07, 6.5ms
# Speed: 4.0ms preprocess, 6.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.47, focus 0.39, distracted 0.14, 6.5ms
# Speed: 4.3ms preprocess, 6.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.43, tired 0.41, distracted 0.16, 7.0ms
# Speed: 3.8ms preprocess, 7.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.45, focus 0.38, distracted 0.17, 6.5ms
# Speed: 5.0ms preprocess, 6.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.42, tired 0.37, distracted 0.21, 6.5ms
# Speed: 4.5ms preprocess, 6.5ms inference, 1.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.57, focus 0.25, distracted 0.19, 7.3ms
# Speed: 2.5ms preprocess, 7.3ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.72, focus 0.15, distracted 0.12, 6.5ms
# Speed: 3.5ms preprocess, 6.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.49, focus 0.26, distracted 0.25, 6.5ms
# Speed: 4.2ms preprocess, 6.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.58, distracted 0.21, focus 0.21, 6.0ms
# Speed: 3.5ms preprocess, 6.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.73, focus 0.16, distracted 0.12, 7.4ms
# Speed: 2.5ms preprocess, 7.4ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.60, focus 0.29, distracted 0.11, 8.0ms
# Speed: 4.4ms preprocess, 8.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.56, focus 0.34, distracted 0.10, 7.5ms
# Speed: 3.8ms preprocess, 7.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.56, focus 0.34, distracted 0.10, 8.5ms
# Speed: 4.5ms preprocess, 8.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.69, focus 0.25, distracted 0.06, 10.0ms
# Speed: 3.0ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.69, focus 0.24, distracted 0.07, 11.6ms
# Speed: 4.1ms preprocess, 11.6ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.73, focus 0.20, distracted 0.07, 9.5ms
# Speed: 3.0ms preprocess, 9.5ms inference, 1.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.65, focus 0.27, distracted 0.07, 7.5ms
# Speed: 3.5ms preprocess, 7.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.66, focus 0.27, distracted 0.07, 8.0ms
# Speed: 3.8ms preprocess, 8.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.53, focus 0.34, distracted 0.13, 8.3ms
# Speed: 2.0ms preprocess, 8.3ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.58, focus 0.33, distracted 0.09, 7.5ms
# Speed: 3.2ms preprocess, 7.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.53, focus 0.35, distracted 0.12, 7.5ms
# Speed: 3.0ms preprocess, 7.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.67, distracted 0.18, focus 0.16, 8.5ms
# Speed: 3.3ms preprocess, 8.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.65, distracted 0.19, focus 0.16, 8.6ms
# Speed: 3.2ms preprocess, 8.6ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.64, focus 0.23, distracted 0.13, 6.2ms
# Speed: 4.5ms preprocess, 6.2ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.64, focus 0.23, distracted 0.13, 6.5ms
# ...
# Speed: 3.6ms preprocess, 8.6ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.99, distracted 0.01, tired 0.01, 10.1ms
# Speed: 4.1ms preprocess, 10.1ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.98, tired 0.01, distracted 0.01, 8.5ms
# Speed: 5.0ms preprocess, 8.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.97, distracted 0.02, tired 0.01, 9.5ms
# Speed: 4.5ms preprocess, 9.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.97, distracted 0.02, tired 0.01, 11.3ms
# Speed: 4.1ms preprocess, 11.3ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.96, tired 0.02, distracted 0.02, 10.8ms
# Speed: 3.0ms preprocess, 10.8ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.95, tired 0.03, distracted 0.02, 9.1ms
# Speed: 3.5ms preprocess, 9.1ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.90, tired 0.08, distracted 0.02, 7.7ms
# Speed: 3.5ms preprocess, 7.7ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.84, tired 0.13, distracted 0.03, 8.6ms
# Speed: 3.3ms preprocess, 8.6ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.78, tired 0.19, distracted 0.02, 11.7ms
# Speed: 3.2ms preprocess, 11.7ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.81, tired 0.16, distracted 0.04, 9.0ms
# Speed: 3.0ms preprocess, 9.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.75, tired 0.20, distracted 0.04, 8.5ms
# Speed: 3.3ms preprocess, 8.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.77, tired 0.17, distracted 0.06, 7.9ms
# Speed: 3.5ms preprocess, 7.9ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.73, tired 0.18, distracted 0.09, 9.0ms
# Speed: 3.0ms preprocess, 9.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.69, tired 0.20, distracted 0.11, 9.5ms
# Speed: 3.0ms preprocess, 9.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.55, tired 0.35, distracted 0.10, 7.5ms
# Speed: 4.3ms preprocess, 7.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.68, tired 0.24, distracted 0.08, 8.8ms
# Speed: 4.7ms preprocess, 8.8ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.68, tired 0.24, distracted 0.08, 7.0ms
# Speed: 4.5ms preprocess, 7.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.67, focus 0.23, distracted 0.11, 11.5ms
# Speed: 4.5ms preprocess, 11.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.68, focus 0.24, distracted 0.08, 10.0ms
# Speed: 3.0ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.50, focus 0.41, distracted 0.09, 11.5ms
# Speed: 4.4ms preprocess, 11.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.75, tired 0.19, distracted 0.06, 12.0ms
# Speed: 4.0ms preprocess, 12.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.89, tired 0.07, distracted 0.04, 7.5ms
# Speed: 3.5ms preprocess, 7.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.89, tired 0.08, distracted 0.03, 6.3ms
# Speed: 4.5ms preprocess, 6.3ms inference, 0.5ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.92, tired 0.06, distracted 0.02, 8.0ms
# Speed: 3.1ms preprocess, 8.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.91, tired 0.05, distracted 0.04, 6.6ms
# Speed: 4.4ms preprocess, 6.6ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.92, tired 0.05, distracted 0.03, 6.7ms
# Speed: 5.4ms preprocess, 6.7ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.96, tired 0.02, distracted 0.02, 8.0ms
# Speed: 4.8ms preprocess, 8.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.95, tired 0.03, distracted 0.02, 8.5ms
# Speed: 3.5ms preprocess, 8.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.95, tired 0.03, distracted 0.02, 10.6ms
# Speed: 4.7ms preprocess, 10.6ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.90, tired 0.07, distracted 0.03, 9.3ms
# Speed: 4.7ms preprocess, 9.3ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.87, tired 0.08, distracted 0.05, 6.5ms
# Speed: 4.7ms preprocess, 6.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.91, tired 0.06, distracted 0.03, 8.1ms
# Speed: 3.5ms preprocess, 8.1ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.85, tired 0.11, distracted 0.04, 9.0ms
# Speed: 3.5ms preprocess, 9.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.77, tired 0.16, distracted 0.06, 9.0ms
# Speed: 4.0ms preprocess, 9.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.72, tired 0.21, distracted 0.07, 8.5ms
# Speed: 3.0ms preprocess, 8.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.46, focus 0.45, distracted 0.09, 9.0ms
# Speed: 4.0ms preprocess, 9.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.65, focus 0.25, distracted 0.11, 6.1ms
# Speed: 5.4ms preprocess, 6.1ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.67, focus 0.24, distracted 0.09, 6.5ms
# Speed: 4.4ms preprocess, 6.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.74, focus 0.18, distracted 0.08, 11.0ms
# Speed: 4.6ms preprocess, 11.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.83, focus 0.10, distracted 0.07, 10.7ms
# Speed: 5.3ms preprocess, 10.7ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.78, focus 0.13, distracted 0.10, 9.0ms
# Speed: 3.5ms preprocess, 9.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.75, focus 0.13, distracted 0.11, 10.5ms
# Speed: 3.5ms preprocess, 10.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.81, distracted 0.10, focus 0.09, 10.5ms
# Speed: 4.0ms preprocess, 10.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.71, focus 0.16, distracted 0.13, 7.5ms
# Speed: 3.7ms preprocess, 7.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.76, focus 0.14, distracted 0.09, 8.5ms
# Speed: 3.4ms preprocess, 8.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.70, focus 0.19, distracted 0.11, 7.5ms
# Speed: 3.2ms preprocess, 7.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.72, focus 0.17, distracted 0.10, 7.0ms
# Speed: 3.5ms preprocess, 7.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.81, focus 0.12, distracted 0.07, 10.5ms
# Speed: 3.4ms preprocess, 10.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.69, focus 0.23, distracted 0.08, 9.7ms
# Speed: 3.3ms preprocess, 9.7ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.46, focus 0.42, distracted 0.12, 6.3ms
# Speed: 3.5ms preprocess, 6.3ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.46, focus 0.44, distracted 0.10, 7.5ms
# Speed: 2.8ms preprocess, 7.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.49, focus 0.41, distracted 0.10, 7.5ms
# Speed: 4.0ms preprocess, 7.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.53, focus 0.37, distracted 0.10, 7.5ms
# Speed: 3.0ms preprocess, 7.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.63, focus 0.29, distracted 0.08, 7.0ms
# Speed: 4.6ms preprocess, 7.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.54, focus 0.38, distracted 0.09, 7.9ms
# Speed: 3.3ms preprocess, 7.9ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.50, focus 0.39, distracted 0.10, 9.5ms
# Speed: 3.0ms preprocess, 9.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.48, focus 0.41, distracted 0.11, 7.5ms
# Speed: 3.0ms preprocess, 7.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.47, focus 0.41, distracted 0.12, 6.9ms
# Speed: 3.9ms preprocess, 6.9ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.56, focus 0.32, distracted 0.11, 7.0ms
# Speed: 3.3ms preprocess, 7.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.49, focus 0.41, distracted 0.10, 11.8ms
# Speed: 3.1ms preprocess, 11.8ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.53, focus 0.37, distracted 0.10, 12.0ms
# Speed: 4.1ms preprocess, 12.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.54, focus 0.38, distracted 0.09, 13.0ms
# Speed: 3.7ms preprocess, 13.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.58, focus 0.33, distracted 0.10, 11.5ms
# Speed: 4.0ms preprocess, 11.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.47, focus 0.41, distracted 0.12, 7.5ms
# Speed: 3.5ms preprocess, 7.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.51, focus 0.40, distracted 0.09, 9.0ms
# Speed: 4.0ms preprocess, 9.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.51, focus 0.38, distracted 0.10, 8.5ms
# Speed: 3.5ms preprocess, 8.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.50, focus 0.37, distracted 0.13, 9.0ms
# Speed: 3.2ms preprocess, 9.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.46, focus 0.42, distracted 0.12, 8.9ms
# Speed: 3.0ms preprocess, 8.9ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.45, tired 0.44, distracted 0.11, 9.0ms
# Speed: 3.2ms preprocess, 9.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.48, focus 0.39, distracted 0.14, 10.5ms
# Speed: 3.5ms preprocess, 10.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.55, focus 0.31, distracted 0.13, 11.1ms
# Speed: 4.5ms preprocess, 11.1ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.54, focus 0.34, distracted 0.13, 7.6ms
# Speed: 3.0ms preprocess, 7.6ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.53, focus 0.33, distracted 0.14, 7.8ms
# Speed: 2.5ms preprocess, 7.8ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.47, focus 0.40, distracted 0.13, 6.7ms
# Speed: 4.9ms preprocess, 6.7ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.43, focus 0.40, distracted 0.17, 7.6ms
# Speed: 4.9ms preprocess, 7.6ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.49, focus 0.36, distracted 0.15, 7.0ms
# Speed: 4.3ms preprocess, 7.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.48, focus 0.39, distracted 0.13, 9.5ms
# Speed: 4.5ms preprocess, 9.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.47, focus 0.34, distracted 0.19, 9.2ms
# Speed: 2.8ms preprocess, 9.2ms inference, 1.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.45, focus 0.39, distracted 0.16, 9.8ms
# Speed: 3.2ms preprocess, 9.8ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.47, focus 0.40, distracted 0.13, 8.7ms
# Speed: 3.0ms preprocess, 8.7ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.47, tired 0.40, distracted 0.13, 7.5ms
# Speed: 3.2ms preprocess, 7.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.46, tired 0.40, distracted 0.14, 7.7ms
# Speed: 3.0ms preprocess, 7.7ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.49, tired 0.40, distracted 0.11, 7.5ms
# Speed: 4.0ms preprocess, 7.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.55, tired 0.32, distracted 0.12, 7.5ms
# Speed: 4.3ms preprocess, 7.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.51, tired 0.35, distracted 0.15, 6.5ms
# Speed: 3.8ms preprocess, 6.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.50, tired 0.38, distracted 0.12, 11.0ms
# Speed: 4.2ms preprocess, 11.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.45, focus 0.41, distracted 0.13, 10.7ms
# Speed: 3.2ms preprocess, 10.7ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.46, tired 0.36, distracted 0.18, 7.0ms
# Speed: 5.4ms preprocess, 7.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.48, tired 0.35, distracted 0.17, 9.5ms
# Speed: 3.5ms preprocess, 9.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.57, tired 0.27, distracted 0.16, 9.0ms
# Speed: 3.0ms preprocess, 9.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.56, tired 0.33, distracted 0.11, 8.5ms
# Speed: 3.0ms preprocess, 8.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.70, tired 0.19, distracted 0.10, 8.7ms
# Speed: 3.2ms preprocess, 8.7ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.81, tired 0.11, distracted 0.08, 10.0ms
# Speed: 3.4ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.79, tired 0.14, distracted 0.07, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.82, tired 0.10, distracted 0.08, 6.8ms
# Speed: 4.5ms preprocess, 6.8ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.76, tired 0.13, distracted 0.11, 7.9ms
# Speed: 3.4ms preprocess, 7.9ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.74, tired 0.15, distracted 0.11, 7.5ms
# Speed: 3.0ms preprocess, 7.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.82, tired 0.10, distracted 0.09, 8.5ms
# Speed: 4.4ms preprocess, 8.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.82, tired 0.10, distracted 0.08, 7.5ms
# Speed: 4.9ms preprocess, 7.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.78, tired 0.11, distracted 0.11, 6.0ms
# Speed: 4.5ms preprocess, 6.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.88, distracted 0.06, tired 0.05, 7.5ms
# Speed: 3.7ms preprocess, 7.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.94, distracted 0.03, tired 0.03, 9.8ms
# Speed: 2.4ms preprocess, 9.8ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)

# %% [markdown]
# ## FACE ID

# %% [markdown]
# ### Test with a photo

# %%
import face_recognition
import cv2
import numpy as np

# Cargar la imagen del rostro conocido y codificarlo
imagen_conocida = face_recognition.load_image_file("image-1.jpg")
encoding_conocido = face_recognition.face_encodings(imagen_conocida)[0]

# Iniciar la captura de video desde la cámara web
video_capture = cv2.VideoCapture(0)

# Variable para almacenar el nombre del individuo reconocido
nombre_recogido = None

while True:
    # Capturar un frame de la cámara
    ret, frame = video_capture.read()

    # Redimensionar el frame para acelerar el procesamiento
    small_frame = cv2.resize(frame, (0, 0), fx=0.25, fy=0.25)

    # Convertir la imagen BGR (OpenCV) a RGB (face_recognition)
    rgb_frame = cv2.cvtColor(small_frame, cv2.COLOR_BGR2RGB)

    # Encontrar todas las caras en el frame actual y obtener sus codificaciones
    face_locations = face_recognition.face_locations(rgb_frame)
    face_encodings = face_recognition.face_encodings(rgb_frame, face_locations)

    for face_encoding in face_encodings:
        # Comparar la codificación de la cara capturada con la codificación del rostro conocido
        matches = face_recognition.compare_faces([encoding_conocido], face_encoding, tolerance=0.6)

        # El método compare_faces devuelve una lista de booleanos. Si hay un True, es una coincidencia
        if True in matches:
            nombre_recogido = "Persona conocida"
        else:
            nombre_recogido = "Desconocido"

    # Mostrar el nombre de la persona en el video
    for (top, right, bottom, left) in face_locations:
        # Escalar de vuelta el tamaño de los cuadros a la imagen original (que fue reducida)
        top *= 4
        right *= 4
        bottom *= 4
        left *= 4

        # Dibujar un rectángulo alrededor de la cara
        cv2.rectangle(frame, (left, top), (right, bottom), (0, 255, 0), 2)

        # Colocar el nombre debajo del cuadro
        cv2.putText(frame, nombre_recogido, (left, bottom + 20), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2)

    # Mostrar el frame
    cv2.imshow('Video', frame)

    # Presionar 'q' para salir del loop
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Liberar la captura de video y cerrar las ventanas
video_capture.release()
cv2.destroyAllWindows()

# %% [markdown]
# ### Save the photo and info at the same instant

# %%
import cv2
import face_recognition
import pickle
import os
import pandas as pd

# Ruta donde almacenaremos las imágenes y datos de las personas conocidas
database_path = "info-people/images"
data_file = "info-people/face_data.pkl"
# Archivo donde guardaremos los datos de las personas
data_frame_file = "info-people/people_data.csv"

# Verificar si la carpeta para guardar las caras conocidas existe, si no, crearla
if not os.path.exists(database_path):
    os.makedirs(database_path)

# Cargar los datos de rostros conocidos (si existen)
if os.path.exists(data_file):
    with open(data_file, "rb") as f:
        known_face_encodings, known_face_ids = pickle.load(f)  # Cargar IDs junto con encodings
else:
    known_face_encodings = []
    known_face_ids = []

# Cargar datos de personas desde el CSV, si existe
if os.path.exists(data_frame_file):
    people_data = pd.read_csv(data_frame_file)
else:
    # Si no existe, crear un DataFrame vacío
    people_data = pd.DataFrame(columns=["ID", "Name", "Age", "Gender"])

# Función para guardar nuevos rostros en la base de datos
def save_new_face(face_encoding, name, age, gender, frame):
    # Generar un ID único
    person_id = len(known_face_encodings) + 1
    known_face_encodings.append(face_encoding)
    known_face_ids.append(person_id)  # Guardar el ID en lugar del nombre

    # Guardar en un archivo los rostros conocidos y sus IDs
    with open(data_file, "wb") as f:
        pickle.dump((known_face_encodings, known_face_ids), f)

    # Guardar la imagen de la persona en la carpeta específica con formato ID-Name
    image_path = f"{database_path}/{person_id}.jpg"
    cv2.imwrite(image_path, frame)

    # Guardar los datos en el DataFrame
    global people_data
    # Crear un nuevo DataFrame para la nueva persona
    new_data = pd.DataFrame({"ID": [person_id], "Name": [name], "Age": [age], "Gender": [gender]})

    # Concatenar el nuevo DataFrame con el existente
    people_data = pd.concat([people_data, new_data], ignore_index=True)

    # Guardar el DataFrame en un archivo CSV
    people_data.to_csv(data_frame_file, index=False)

# Inicializar la cámara
video_capture = cv2.VideoCapture(0)

while True:
    # Capturar el video en tiempo real
    ret, frame = video_capture.read()

    # Convertir la imagen de BGR (OpenCV) a RGB (face_recognition usa RGB)
    rgb_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

    # Buscar los rostros en la imagen y codificarlos
    face_locations = face_recognition.face_locations(rgb_frame)
    face_encodings = face_recognition.face_encodings(rgb_frame, face_locations)

    for (top, right, bottom, left), face_encoding in zip(face_locations, face_encodings):
        # Comprobar si el rostro es conocido
        matches = face_recognition.compare_faces(known_face_encodings, face_encoding)

        person_id = None
        name = "Desconocido"

        # Si hay coincidencias
        if True in matches:
            first_match_index = matches.index(True)
            person_id = known_face_ids[first_match_index]  # Obtener el ID correspondiente
            # Acceder al nombre usando el ID
            name = people_data.loc[people_data['ID'] == person_id, 'Name'].values[0]  # Obtener el nombre usando el ID
        else:
            # Si es un rostro nuevo, preguntar el nombre, edad y género
            name = input("No te reconozco, ¿Cuál es tu nombre?: ")
            age = input("¿Cuál es tu edad?: ")
            gender = input("¿Cuál es tu género?: (M o F)")

            # Guardar el nuevo rostro
            save_new_face(face_encoding, name, age, gender, frame)

        # Dibujar un cuadro alrededor del rostro
        cv2.rectangle(frame, (left, top), (right, bottom), (0, 255, 0), 2)

        # Escribir el nombre debajo del rostro
        cv2.rectangle(frame, (left, bottom - 35), (right, bottom), (0, 255, 0), cv2.FILLED)
        font = cv2.FONT_HERSHEY_DUPLEX
        cv2.putText(frame, name, (left + 6, bottom - 6), font, 1.0, (255, 255, 255), 1)

    # Mostrar el video
    cv2.imshow('Video', frame)

    # Salir del bucle con 'q'
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Liberar la cámara y cerrar las ventanas
video_capture.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[1], line 66
#      63 ret, frame = video_capture.read()
#      65 # Convertir la imagen de BGR (OpenCV) a RGB (face_recognition usa RGB)
# ---> 66 rgb_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
#      68 # Buscar los rostros en la imagen y codificarlos
#      69 face_locations = face_recognition.face_locations(rgb_frame)
#
# error: OpenCV(4.10.0) C:\b\abs_daut97tdpo\croot\opencv-suite_1722029138522\work\modules\imgproc\src\color.cpp:196: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'

# %% [markdown]
# ## JOIN CODES

# %%
import cv2
import pickle
import os
import pandas as pd

from datetime import datetime
from ultralytics import YOLO
import winsound

from functions import save_prediction, alerta_sonora, faceid_init


# Ruta donde almacenaremos las imágenes y datos de las personas conocidas
database_path = "info-people/images"
data_file = "info-people/face_data.pkl"
# Archivo donde guardaremos los datos de las personas
data_frame_file = "info-people/people_data.csv"
data_status = "info-people/status-csv"

# Verificar si la carpeta para guardar las caras conocidas existe, si no, crearla
if not os.path.exists(database_path):
    os.makedirs(database_path)

# Cargar los datos de rostros conocidos (si existen)
if os.path.exists(data_file):
    with open(data_file, "rb") as f:
        known_face_encodings, known_face_ids = pickle.load(f)  # Cargar IDs junto con encodings
else:
    known_face_encodings = []
    known_face_ids = []

# Cargar datos de personas desde el CSV, si existe
if os.path.exists(data_frame_file):
    people_data = pd.read_csv(data_frame_file)
else:
    # Si no existe, crear un DataFrame vacío
    people_data = pd.DataFrame(columns=["ID", "Name", "Age", "Gender"])

if os.path.exists(data_status):
    df = pd.read_csv(data_status)
else:
    # Si no existe, crear un DataFrame vacío
    df = pd.DataFrame(columns=["id","timestamp", "status", "probability"])


# Inicializar YOLO con tu modelo personalizado
model = YOLO('model/model_3x2.pt')

# Inicializamos el contador de tiempo consecutivo de "tired"
contador_cansado = 0
umbral_alerta = 2  # Umbral de 2 segundos para generar alerta
intervalo_frame = 0.1  # Suponemos que las predicciones se generan cada 100 ms (0.1 segundos)

# Inicializar la cámara
video_capture = cv2.VideoCapture(0)

faceid = True
while True:
    # Capturar el video en tiempo real
    ret, frame = video_capture.read()
    
    if faceid == True:
        name, person_id = faceid_init(frame, known_face_encodings, known_face_ids, data_file, database_path, data_frame_file, people_data)
        
        faceid = False
        
    else:
        # Procesar el frame con YOLO
        results = model(frame)

        # Obtener las detecciones
        detections = results[0].names[results[0].probs.top1]
        probabilidad = results[0].probs.top1conf.item()  # Obtener la probabilidad más alta de la predicción

        # Guardar la predicción en el DataFrame
        df = save_prediction(detections, probabilidad, person_id, df)

        # Verificar si el estado actual es "tired"
        if detections == "tired":
            contador_cansado += intervalo_frame  # Aumentamos el contador en 0.1 segundos
        else:
            contador_cansado = 0  # Si no está cansado, reiniciamos el contador

        # Si el conductor ha estado "tired" por más de 2 segundos, generamos una alerta
        if contador_cansado >= umbral_alerta:
            alerta_sonora()
            contador_cansado = 0  # Reiniciar el contador tras la alerta para evitar repetidas alertas

        # Mostrar el estado en la ventana de video
        cv2.putText(frame, f'{name}: {detections}', (50, 50), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2)

    # Mostrar el video
    cv2.imshow('Video', frame)

    # Salir del bucle con 'q'
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Liberar la cámara y cerrar las ventanas

video_capture.release()
cv2.destroyAllWindows()
# Guardar el DataFrame en un archivo CSV para análisis posterior si es necesario
df.to_csv("info-people/status.csv", index=False)
# Out:
# 0: 128x128 focus 0.92, tired 0.04, distracted 0.04, 17.8ms
# Speed: 9.4ms preprocess, 17.8ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.67, distracted 0.32, focus 0.01, 11.0ms
# Speed: 3.6ms preprocess, 11.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.79, distracted 0.19, focus 0.02, 12.5ms
# Speed: 5.0ms preprocess, 12.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.61, distracted 0.36, focus 0.03, 10.4ms
# Speed: 5.5ms preprocess, 10.4ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.61, distracted 0.36, focus 0.03, 11.1ms
# Speed: 4.5ms preprocess, 11.1ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.61, distracted 0.36, focus 0.03, 12.2ms
# Speed: 3.0ms preprocess, 12.2ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
# c:\Users\Lidia Mayor\Documents\GitHub\finalproject\functions.py:41: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df, nueva_fila], ignore_index=True)
# 0: 128x128 distracted 0.46, tired 0.46, focus 0.08, 14.1ms
# Speed: 3.0ms preprocess, 14.1ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.52, tired 0.44, focus 0.04, 10.0ms
# Speed: 4.0ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.59, distracted 0.37, focus 0.04, 7.7ms
# Speed: 5.5ms preprocess, 7.7ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.47, distracted 0.44, focus 0.09, 10.5ms
# Speed: 4.5ms preprocess, 10.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.45, tired 0.38, focus 0.16, 11.7ms
# Speed: 3.5ms preprocess, 11.7ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.80, distracted 0.12, tired 0.08, 11.6ms
# Speed: 4.1ms preprocess, 11.6ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.49, tired 0.28, distracted 0.23, 9.6ms
# Speed: 3.5ms preprocess, 9.6ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.38, tired 0.32, distracted 0.30, 10.0ms
# Speed: 3.5ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.49, distracted 0.30, tired 0.20, 10.5ms
# Speed: 5.8ms preprocess, 10.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.64, distracted 0.18, tired 0.18, 9.0ms
# Speed: 5.0ms preprocess, 9.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.64, distracted 0.18, tired 0.18, 9.4ms
# Speed: 6.0ms preprocess, 9.4ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.60, distracted 0.21, tired 0.19, 16.4ms
# Speed: 5.1ms preprocess, 16.4ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.58, tired 0.24, distracted 0.18, 11.6ms
# Speed: 3.5ms preprocess, 11.6ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.38, focus 0.35, distracted 0.26, 11.0ms
# Speed: 3.1ms preprocess, 11.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.68, tired 0.19, distracted 0.13, 12.4ms
# Speed: 4.5ms preprocess, 12.4ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.62, tired 0.25, distracted 0.14, 26.8ms
# Speed: 7.0ms preprocess, 26.8ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.47, tired 0.31, distracted 0.22, 30.3ms
# Speed: 64.9ms preprocess, 30.3ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.56, distracted 0.25, tired 0.18, 14.2ms
# Speed: 4.6ms preprocess, 14.2ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.72, tired 0.15, distracted 0.12, 11.0ms
# Speed: 3.3ms preprocess, 11.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.76, tired 0.13, distracted 0.12, 9.5ms
# Speed: 3.5ms preprocess, 9.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.74, distracted 0.14, tired 0.12, 7.1ms
# Speed: 6.5ms preprocess, 7.1ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.80, tired 0.12, distracted 0.08, 10.9ms
# Speed: 5.0ms preprocess, 10.9ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.81, distracted 0.10, tired 0.09, 11.6ms
# Speed: 4.0ms preprocess, 11.6ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.84, tired 0.08, distracted 0.08, 12.8ms
# Speed: 3.5ms preprocess, 12.8ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.68, tired 0.17, distracted 0.15, 9.5ms
# Speed: 3.1ms preprocess, 9.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.69, tired 0.16, distracted 0.15, 8.0ms
# Speed: 4.0ms preprocess, 8.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.74, tired 0.14, distracted 0.12, 8.5ms
# Speed: 3.5ms preprocess, 8.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.68, distracted 0.16, tired 0.15, 9.1ms
# Speed: 6.5ms preprocess, 9.1ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.73, tired 0.15, distracted 0.13, 9.5ms
# Speed: 6.5ms preprocess, 9.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.75, tired 0.14, distracted 0.12, 13.4ms
# Speed: 3.1ms preprocess, 13.4ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.74, tired 0.13, distracted 0.12, 11.0ms
# Speed: 4.3ms preprocess, 11.0ms inference, 0.5ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.70, tired 0.16, distracted 0.14, 12.0ms
# Speed: 2.7ms preprocess, 12.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.76, tired 0.13, distracted 0.11, 9.0ms
# Speed: 3.0ms preprocess, 9.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.70, distracted 0.15, tired 0.15, 8.2ms
# Speed: 6.4ms preprocess, 8.2ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.72, tired 0.16, distracted 0.12, 9.6ms
# Speed: 5.0ms preprocess, 9.6ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.77, tired 0.13, distracted 0.10, 12.2ms
# Speed: 3.0ms preprocess, 12.2ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.68, tired 0.19, distracted 0.13, 12.0ms
# Speed: 3.0ms preprocess, 12.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.75, distracted 0.13, tired 0.13, 39.8ms
# Speed: 6.6ms preprocess, 39.8ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.52, distracted 0.35, focus 0.14, 15.9ms
# Speed: 6.4ms preprocess, 15.9ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.65, distracted 0.28, focus 0.07, 13.1ms
# Speed: 4.1ms preprocess, 13.1ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.50, distracted 0.37, focus 0.13, 10.2ms
# Speed: 4.0ms preprocess, 10.2ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.35, focus 0.33, distracted 0.32, 11.5ms
# Speed: 6.5ms preprocess, 11.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.50, tired 0.27, distracted 0.23, 16.0ms
# Speed: 3.5ms preprocess, 16.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.77, distracted 0.12, tired 0.11, 13.3ms
# Speed: 6.0ms preprocess, 13.3ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.88, tired 0.07, distracted 0.05, 13.8ms
# Speed: 4.0ms preprocess, 13.8ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.91, distracted 0.05, tired 0.04, 13.1ms
# Speed: 3.4ms preprocess, 13.1ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.93, distracted 0.04, tired 0.03, 11.5ms
# Speed: 4.3ms preprocess, 11.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.96, distracted 0.02, tired 0.02, 10.5ms
# Speed: 2.9ms preprocess, 10.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.97, tired 0.02, distracted 0.01, 10.0ms
# Speed: 6.0ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.92, tired 0.04, distracted 0.04, 9.5ms
# Speed: 6.0ms preprocess, 9.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.94, tired 0.03, distracted 0.02, 7.4ms
# Speed: 7.0ms preprocess, 7.4ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.89, tired 0.06, distracted 0.05, 11.6ms
# Speed: 4.0ms preprocess, 11.6ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.94, tired 0.03, distracted 0.03, 11.1ms
# Speed: 3.5ms preprocess, 11.1ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.93, tired 0.04, distracted 0.03, 11.5ms
# Speed: 3.0ms preprocess, 11.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.92, tired 0.04, distracted 0.04, 11.4ms
# Speed: 4.0ms preprocess, 11.4ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.97, distracted 0.02, tired 0.02, 10.0ms
# Speed: 4.3ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.95, distracted 0.03, tired 0.02, 8.6ms
# Speed: 4.0ms preprocess, 8.6ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.98, distracted 0.01, tired 0.01, 8.0ms
# Speed: 4.0ms preprocess, 8.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.97, distracted 0.02, tired 0.02, 9.4ms
# Speed: 5.2ms preprocess, 9.4ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.98, distracted 0.01, tired 0.01, 10.5ms
# Speed: 4.4ms preprocess, 10.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.97, distracted 0.01, tired 0.01, 11.1ms
# Speed: 3.0ms preprocess, 11.1ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.95, tired 0.03, distracted 0.02, 10.6ms
# Speed: 3.5ms preprocess, 10.6ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.95, tired 0.03, distracted 0.02, 11.6ms
# Speed: 3.0ms preprocess, 11.6ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.84, tired 0.11, distracted 0.06, 9.7ms
# Speed: 3.5ms preprocess, 9.7ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.93, tired 0.05, distracted 0.03, 9.5ms
# Speed: 2.5ms preprocess, 9.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.81, distracted 0.11, tired 0.08, 7.5ms
# Speed: 3.0ms preprocess, 7.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.75, distracted 0.13, tired 0.12, 7.5ms
# Speed: 5.0ms preprocess, 7.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.50, distracted 0.34, tired 0.16, 8.0ms
# Speed: 5.9ms preprocess, 8.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.57, tired 0.25, focus 0.18, 11.0ms
# Speed: 4.0ms preprocess, 11.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.47, tired 0.36, focus 0.16, 10.0ms
# Speed: 3.7ms preprocess, 10.0ms inference, 0.3ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.47, distracted 0.42, focus 0.11, 10.0ms
# Speed: 3.5ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.59, tired 0.33, focus 0.08, 12.5ms
# Speed: 4.0ms preprocess, 12.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.48, tired 0.45, focus 0.07, 12.9ms
# Speed: 4.0ms preprocess, 12.9ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.68, tired 0.25, focus 0.08, 7.5ms
# Speed: 4.0ms preprocess, 7.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.60, tired 0.32, focus 0.09, 7.5ms
# Speed: 5.0ms preprocess, 7.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.64, tired 0.31, focus 0.05, 8.0ms
# Speed: 4.5ms preprocess, 8.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.65, tired 0.27, focus 0.08, 11.5ms
# Speed: 3.5ms preprocess, 11.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.72, tired 0.24, focus 0.04, 9.7ms
# Speed: 3.5ms preprocess, 9.7ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.71, tired 0.26, focus 0.02, 9.5ms
# Speed: 3.5ms preprocess, 9.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.62, tired 0.34, focus 0.04, 8.5ms
# Speed: 4.5ms preprocess, 8.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.66, tired 0.28, focus 0.05, 8.0ms
# Speed: 3.5ms preprocess, 8.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.72, tired 0.23, focus 0.05, 7.5ms
# Speed: 3.2ms preprocess, 7.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.78, tired 0.17, focus 0.05, 8.5ms
# Speed: 5.0ms preprocess, 8.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.74, tired 0.20, focus 0.06, 8.5ms
# Speed: 4.8ms preprocess, 8.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.78, tired 0.16, focus 0.06, 11.2ms
# Speed: 3.8ms preprocess, 11.2ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.81, tired 0.14, focus 0.05, 9.0ms
# Speed: 3.7ms preprocess, 9.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.74, tired 0.20, focus 0.06, 8.8ms
# Speed: 4.5ms preprocess, 8.8ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.52, tired 0.32, focus 0.16, 10.0ms
# Speed: 3.0ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.61, tired 0.29, focus 0.10, 9.5ms
# Speed: 3.4ms preprocess, 9.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.47, tired 0.42, focus 0.11, 7.0ms
# Speed: 3.5ms preprocess, 7.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.48, tired 0.46, focus 0.06, 8.6ms
# Speed: 3.5ms preprocess, 8.6ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.46, distracted 0.45, focus 0.09, 9.9ms
# Speed: 3.9ms preprocess, 9.9ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.67, tired 0.23, focus 0.10, 7.5ms
# Speed: 3.1ms preprocess, 7.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.67, focus 0.18, tired 0.15, 7.0ms
# Speed: 3.5ms preprocess, 7.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.47, focus 0.42, tired 0.11, 8.1ms
# Speed: 3.0ms preprocess, 8.1ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.47, focus 0.37, tired 0.17, 9.0ms
# Speed: 3.0ms preprocess, 9.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.45, distracted 0.33, tired 0.22, 10.0ms
# Speed: 3.5ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.48, focus 0.31, tired 0.21, 9.4ms
# Speed: 3.5ms preprocess, 9.4ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.44, tired 0.42, focus 0.14, 9.5ms
# Speed: 4.5ms preprocess, 9.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.46, tired 0.39, focus 0.15, 12.6ms
# Speed: 4.0ms preprocess, 12.6ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.51, tired 0.45, focus 0.04, 13.2ms
# Speed: 3.4ms preprocess, 13.2ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.78, tired 0.19, focus 0.02, 10.1ms
# Speed: 4.5ms preprocess, 10.1ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.93, tired 0.06, focus 0.01, 8.5ms
# Speed: 5.3ms preprocess, 8.5ms inference, 1.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.93, tired 0.06, focus 0.02, 10.5ms
# Speed: 3.4ms preprocess, 10.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.88, tired 0.09, focus 0.03, 10.2ms
# Speed: 4.3ms preprocess, 10.2ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.96, tired 0.02, focus 0.01, 9.5ms
# Speed: 3.0ms preprocess, 9.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.95, tired 0.04, focus 0.01, 8.2ms
# Speed: 3.5ms preprocess, 8.2ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.90, tired 0.08, focus 0.01, 8.5ms
# Speed: 4.0ms preprocess, 8.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.91, tired 0.08, focus 0.02, 7.5ms
# Speed: 3.0ms preprocess, 7.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.93, tired 0.06, focus 0.01, 7.5ms
# Speed: 4.2ms preprocess, 7.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.90, tired 0.07, focus 0.02, 9.0ms
# Speed: 3.0ms preprocess, 9.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.88, tired 0.09, focus 0.02, 10.5ms
# Speed: 3.1ms preprocess, 10.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.88, tired 0.10, focus 0.03, 10.0ms
# Speed: 3.0ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.89, tired 0.09, focus 0.02, 8.8ms
# Speed: 3.5ms preprocess, 8.8ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.84, tired 0.13, focus 0.02, 8.0ms
# Speed: 3.5ms preprocess, 8.0ms inference, 0.5ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.87, tired 0.12, focus 0.01, 7.0ms
# Speed: 4.0ms preprocess, 7.0ms inference, 1.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.81, tired 0.17, focus 0.02, 8.5ms
# Speed: 3.4ms preprocess, 8.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.76, tired 0.22, focus 0.02, 8.1ms
# Speed: 4.5ms preprocess, 8.1ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.63, tired 0.36, focus 0.01, 8.0ms
# Speed: 4.5ms preprocess, 8.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.66, tired 0.33, focus 0.01, 8.5ms
# Speed: 4.0ms preprocess, 8.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.63, tired 0.36, focus 0.01, 9.7ms
# Speed: 2.3ms preprocess, 9.7ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.70, tired 0.29, focus 0.01, 9.5ms
# Speed: 3.5ms preprocess, 9.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.62, tired 0.37, focus 0.02, 7.5ms
# Speed: 4.7ms preprocess, 7.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.67, tired 0.31, focus 0.02, 8.5ms
# Speed: 3.5ms preprocess, 8.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.58, tired 0.40, focus 0.02, 9.6ms
# Speed: 2.8ms preprocess, 9.6ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.63, tired 0.36, focus 0.01, 9.5ms
# Speed: 3.5ms preprocess, 9.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.61, tired 0.36, focus 0.02, 8.5ms
# Speed: 4.5ms preprocess, 8.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.67, tired 0.30, focus 0.03, 7.0ms
# Speed: 3.7ms preprocess, 7.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.59, tired 0.35, focus 0.06, 10.5ms
# Speed: 5.0ms preprocess, 10.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.55, tired 0.43, focus 0.03, 11.0ms
# Speed: 5.0ms preprocess, 11.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.58, tired 0.38, focus 0.04, 8.2ms
# Speed: 4.5ms preprocess, 8.2ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.55, tired 0.41, focus 0.05, 7.5ms
# Speed: 4.5ms preprocess, 7.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.54, distracted 0.41, focus 0.06, 8.5ms
# Speed: 5.0ms preprocess, 8.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.53, tired 0.41, focus 0.06, 9.7ms
# Speed: 3.5ms preprocess, 9.7ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.56, tired 0.39, focus 0.06, 9.5ms
# Speed: 3.5ms preprocess, 9.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.49, tired 0.42, focus 0.09, 9.0ms
# Speed: 3.6ms preprocess, 9.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.55, tired 0.35, focus 0.09, 9.2ms
# Speed: 3.5ms preprocess, 9.2ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.56, focus 0.23, tired 0.22, 9.5ms
# Speed: 5.0ms preprocess, 9.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.50, focus 0.36, tired 0.14, 7.7ms
# Speed: 3.5ms preprocess, 7.7ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.48, focus 0.34, tired 0.18, 8.4ms
# Speed: 3.0ms preprocess, 8.4ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)

# %%
import cv2
import pickle
import os
import pandas as pd

from datetime import datetime
from ultralytics import YOLO



# Ruta donde almacenaremos las imágenes y datos de las personas conocidas
database_path = "info-people/images"
data_file = "info-people/face_data.pkl"
# Archivo donde guardaremos los datos de las personas
data_frame_file = "info-people/people_data.csv"
data_status = "info-people/status-csv"

# Verificar si la carpeta para guardar las caras conocidas existe, si no, crearla
if not os.path.exists(database_path):
    os.makedirs(database_path)

if os.path.exists(data_frame_file):
    people_data = pd.read_csv(data_frame_file)
else:
    # Si no existe, crear un DataFrame vacío
    people_data = pd.DataFrame(columns=["ID", "Name", "Age", "Gender"])


# Crear un nuevo DataFrame para la nueva persona

person_id=1
name = 'Lidia'
age = 23
gender = 'F'

new_data = pd.DataFrame({"ID": [person_id], "Name": [name], "Age": [age], "Gender": [gender]})

# Concatenar el nuevo DataFrame con el existente
people_data = pd.concat([people_data, new_data], ignore_index=True)

# Guardar el DataFrame en un archivo CSV
people_data.to_csv(data_frame_file, index=False)

# %% [markdown]
# # WITH CLASS

# %%
import cv2
from driving_attention import DrivingAttention


# Ruta donde almacenaremos las imágenes y datos de las personas conocidas
database_path = "info-people/images"
data_file = "info-people/face_data.pkl"
# Archivo donde guardaremos los datos de las personas
data_frame_file = "info-people/people_data.csv"
data_status = "info-people/status.csv"
# Ruta del modelo
model_path = "model/model_3x2.pt"

da = DrivingAttention(model_path, database_path, data_file, data_frame_file, data_status)

# Inicializar la cámara
video_capture = da.start_video_capture()

faceid = True

while True:
    # Capturar el video en tiempo real
    da.read_video()

    if faceid == True:
        da.faceid_init()
        faceid = False     
    else:
        da.prediction()     

    # Mostrar el video
    da.video_show()

    # Salir del bucle con 'q'
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
# Liberar la cámara y cerrar las ventanas
da.finish()
cv2.destroyAllWindows()
# Out:
# 0: 128x128 focus 0.45, distracted 0.35, tired 0.20, 78.5ms
# Speed: 38.5ms preprocess, 78.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.52, distracted 0.36, tired 0.11, 4.0ms
# Speed: 5.2ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.63, distracted 0.28, tired 0.09, 15.3ms
# Speed: 0.0ms preprocess, 15.3ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.57, distracted 0.32, tired 0.11, 10.1ms
# Speed: 4.6ms preprocess, 10.1ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.47, distracted 0.36, tired 0.17, 12.8ms
# Speed: 0.0ms preprocess, 12.8ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.38, distracted 0.38, tired 0.23, 9.7ms
# Speed: 2.9ms preprocess, 9.7ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.39, distracted 0.38, tired 0.23, 15.0ms
# Speed: 0.0ms preprocess, 15.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.41, distracted 0.40, tired 0.19, 16.6ms
# Speed: 0.0ms preprocess, 16.6ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.41, distracted 0.38, tired 0.21, 12.7ms
# Speed: 4.3ms preprocess, 12.7ms inference, 0.1ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.45, focus 0.32, tired 0.22, 9.2ms
# Speed: 3.5ms preprocess, 9.2ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.46, focus 0.33, tired 0.21, 8.7ms
# Speed: 3.1ms preprocess, 8.7ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.43, distracted 0.39, tired 0.18, 10.2ms
# Speed: 1.1ms preprocess, 10.2ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.48, focus 0.29, tired 0.23, 11.2ms
# Speed: 0.6ms preprocess, 11.2ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.42, focus 0.36, tired 0.23, 12.3ms
# Speed: 0.0ms preprocess, 12.3ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.48, distracted 0.34, tired 0.17, 7.8ms
# Speed: 4.0ms preprocess, 7.8ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.42, distracted 0.40, tired 0.18, 10.5ms
# Speed: 3.0ms preprocess, 10.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.46, distracted 0.35, tired 0.19, 16.1ms
# Speed: 0.0ms preprocess, 16.1ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.41, distracted 0.39, tired 0.20, 9.3ms
# Speed: 3.5ms preprocess, 9.3ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.46, focus 0.38, tired 0.16, 10.4ms
# Speed: 4.5ms preprocess, 10.4ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.44, distracted 0.41, tired 0.15, 8.4ms
# Speed: 4.0ms preprocess, 8.4ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.49, distracted 0.36, tired 0.16, 10.6ms
# Speed: 1.1ms preprocess, 10.6ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.54, distracted 0.35, tired 0.11, 11.7ms
# Speed: 0.0ms preprocess, 11.7ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.54, distracted 0.32, tired 0.13, 7.0ms
# Speed: 0.8ms preprocess, 7.0ms inference, 3.4ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.50, distracted 0.36, tired 0.15, 45.3ms
# Speed: 3.9ms preprocess, 45.3ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.53, distracted 0.34, tired 0.13, 10.0ms
# Speed: 1.6ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.45, distracted 0.41, tired 0.15, 11.1ms
# Speed: 2.5ms preprocess, 11.1ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.56, distracted 0.29, tired 0.14, 7.8ms
# Speed: 3.5ms preprocess, 7.8ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.46, focus 0.41, tired 0.12, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.43, focus 0.38, tired 0.19, 8.0ms
# Speed: 3.3ms preprocess, 8.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.42, focus 0.33, tired 0.25, 0.0ms
# Speed: 4.9ms preprocess, 0.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.39, focus 0.38, tired 0.22, 7.1ms
# Speed: 3.5ms preprocess, 7.1ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.44, distracted 0.31, tired 0.25, 8.4ms
# Speed: 2.6ms preprocess, 8.4ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.40, focus 0.36, tired 0.25, 8.6ms
# Speed: 4.2ms preprocess, 8.6ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.37, focus 0.35, tired 0.28, 24.3ms
# Speed: 2.1ms preprocess, 24.3ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.40, distracted 0.35, tired 0.25, 17.0ms
# Speed: 3.5ms preprocess, 17.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.38, focus 0.37, tired 0.26, 19.8ms
# Speed: 0.0ms preprocess, 19.8ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.38, distracted 0.35, tired 0.27, 12.0ms
# Speed: 2.5ms preprocess, 12.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.42, focus 0.35, tired 0.23, 17.3ms
# Speed: 3.3ms preprocess, 17.3ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.41, focus 0.35, tired 0.24, 13.1ms
# Speed: 5.7ms preprocess, 13.1ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.39, distracted 0.35, tired 0.26, 33.6ms
# Speed: 1.6ms preprocess, 33.6ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.39, distracted 0.38, tired 0.23, 28.2ms
# Speed: 4.0ms preprocess, 28.2ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 distracted 0.38, focus 0.35, tired 0.28, 21.1ms
# Speed: 0.0ms preprocess, 21.1ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.42, distracted 0.34, tired 0.24, 81.0ms
# Speed: 0.0ms preprocess, 81.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.42, distracted 0.32, tired 0.25, 34.5ms
# Speed: 8.8ms preprocess, 34.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.43, distracted 0.35, tired 0.22, 92.5ms
# Speed: 5.0ms preprocess, 92.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.46, distracted 0.41, tired 0.13, 9.5ms
# Speed: 7.8ms preprocess, 9.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.50, distracted 0.38, tired 0.12, 9.7ms
# Speed: 4.0ms preprocess, 9.7ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.54, distracted 0.32, tired 0.14, 13.4ms
# Speed: 2.1ms preprocess, 13.4ms inference, 1.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.55, distracted 0.29, tired 0.16, 1.6ms
# Speed: 3.0ms preprocess, 1.6ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.55, distracted 0.29, tired 0.16, 12.6ms
# Speed: 3.0ms preprocess, 12.6ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.50, distracted 0.33, tired 0.17, 2.6ms
# Speed: 4.5ms preprocess, 2.6ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.47, distracted 0.36, tired 0.16, 11.7ms
# Speed: 4.4ms preprocess, 11.7ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.63, distracted 0.27, tired 0.10, 12.3ms
# Speed: 4.3ms preprocess, 12.3ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.47, distracted 0.38, tired 0.16, 13.0ms
# Speed: 5.2ms preprocess, 13.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.60, distracted 0.32, tired 0.08, 13.5ms
# Speed: 2.9ms preprocess, 13.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.55, distracted 0.35, tired 0.10, 15.2ms
# Speed: 1.0ms preprocess, 15.2ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.53, distracted 0.36, tired 0.10, 16.4ms
# Speed: 0.0ms preprocess, 16.4ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.63, distracted 0.28, tired 0.09, 16.1ms
# Speed: 1.0ms preprocess, 16.1ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.70, distracted 0.22, tired 0.08, 12.5ms
# Speed: 4.1ms preprocess, 12.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.43, distracted 0.40, tired 0.16, 13.0ms
# Speed: 0.5ms preprocess, 13.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.64, distracted 0.24, tired 0.12, 14.8ms
# Speed: 0.0ms preprocess, 14.8ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.90, tired 0.05, distracted 0.04, 16.1ms
# Speed: 0.0ms preprocess, 16.1ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.77, tired 0.13, distracted 0.10, 10.7ms
# Speed: 4.3ms preprocess, 10.7ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.85, tired 0.08, distracted 0.08, 12.3ms
# Speed: 5.1ms preprocess, 12.3ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.91, tired 0.05, distracted 0.04, 13.4ms
# Speed: 3.2ms preprocess, 13.4ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.90, tired 0.06, distracted 0.04, 11.7ms
# Speed: 4.9ms preprocess, 11.7ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.93, tired 0.04, distracted 0.03, 14.9ms
# Speed: 1.5ms preprocess, 14.9ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.93, tired 0.04, distracted 0.03, 14.1ms
# Speed: 2.5ms preprocess, 14.1ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.87, tired 0.08, distracted 0.06, 11.8ms
# Speed: 3.6ms preprocess, 11.8ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.88, distracted 0.06, tired 0.06, 12.2ms
# Speed: 4.5ms preprocess, 12.2ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.76, tired 0.13, distracted 0.11, 11.8ms
# Speed: 5.0ms preprocess, 11.8ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.76, tired 0.13, distracted 0.11, 11.4ms
# Speed: 4.8ms preprocess, 11.4ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.69, tired 0.17, distracted 0.14, 14.1ms
# Speed: 2.5ms preprocess, 14.1ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.87, tired 0.07, distracted 0.06, 16.2ms
# Speed: 2.0ms preprocess, 16.2ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.77, tired 0.14, distracted 0.09, 11.2ms
# Speed: 5.2ms preprocess, 11.2ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.79, tired 0.13, distracted 0.08, 15.9ms
# Speed: 2.0ms preprocess, 15.9ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.80, tired 0.11, distracted 0.09, 17.9ms
# Speed: 0.0ms preprocess, 17.9ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.68, distracted 0.17, tired 0.15, 13.4ms
# Speed: 4.1ms preprocess, 13.4ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.87, distracted 0.09, tired 0.04, 13.4ms
# Speed: 5.1ms preprocess, 13.4ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.89, distracted 0.06, tired 0.05, 10.5ms
# Speed: 5.1ms preprocess, 10.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.92, distracted 0.05, tired 0.04, 11.3ms
# Speed: 4.1ms preprocess, 11.3ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.89, distracted 0.07, tired 0.04, 12.2ms
# Speed: 4.6ms preprocess, 12.2ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.84, distracted 0.09, tired 0.07, 8.7ms
# Speed: 5.5ms preprocess, 8.7ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.82, tired 0.10, distracted 0.09, 12.2ms
# Speed: 5.1ms preprocess, 12.2ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.82, tired 0.10, distracted 0.09, 13.0ms
# Speed: 4.0ms preprocess, 13.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.62, tired 0.19, distracted 0.19, 11.9ms
# Speed: 4.7ms preprocess, 11.9ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.49, tired 0.30, distracted 0.21, 13.5ms
# Speed: 4.9ms preprocess, 13.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.56, tired 0.24, distracted 0.20, 12.2ms
# Speed: 2.5ms preprocess, 12.2ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.55, tired 0.25, distracted 0.20, 13.7ms
# Speed: 3.9ms preprocess, 13.7ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.56, tired 0.30, distracted 0.14, 11.8ms
# Speed: 5.4ms preprocess, 11.8ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.42, focus 0.41, distracted 0.17, 10.7ms
# Speed: 4.8ms preprocess, 10.7ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.41, focus 0.39, distracted 0.19, 13.1ms
# Speed: 4.5ms preprocess, 13.1ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.43, tired 0.41, distracted 0.17, 13.6ms
# Speed: 4.0ms preprocess, 13.6ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.43, focus 0.41, distracted 0.16, 15.1ms
# Speed: 2.2ms preprocess, 15.1ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.45, tired 0.40, distracted 0.16, 15.1ms
# Speed: 4.2ms preprocess, 15.1ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.49, focus 0.29, distracted 0.22, 13.2ms
# Speed: 3.7ms preprocess, 13.2ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.41, focus 0.39, distracted 0.20, 12.6ms
# Speed: 4.3ms preprocess, 12.6ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 tired 0.41, focus 0.39, distracted 0.20, 14.5ms
# Speed: 4.9ms preprocess, 14.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.44, tired 0.33, distracted 0.22, 13.4ms
# Speed: 3.8ms preprocess, 13.4ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.83, tired 0.10, distracted 0.07, 15.9ms
# Speed: 2.4ms preprocess, 15.9ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.86, tired 0.08, distracted 0.06, 15.6ms
# Speed: 1.2ms preprocess, 15.6ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.84, tired 0.09, distracted 0.07, 13.9ms
# Speed: 4.7ms preprocess, 13.9ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.87, tired 0.07, distracted 0.06, 12.5ms
# Speed: 5.4ms preprocess, 12.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.65, tired 0.19, distracted 0.16, 14.2ms
# Speed: 4.7ms preprocess, 14.2ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.65, distracted 0.18, tired 0.17, 14.7ms
# Speed: 2.1ms preprocess, 14.7ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.64, tired 0.19, distracted 0.17, 13.5ms
# Speed: 3.8ms preprocess, 13.5ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.77, distracted 0.13, tired 0.10, 12.6ms
# Speed: 4.6ms preprocess, 12.6ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.82, distracted 0.10, tired 0.08, 12.3ms
# Speed: 5.3ms preprocess, 12.3ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.80, distracted 0.12, tired 0.08, 11.1ms
# Speed: 5.5ms preprocess, 11.1ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.90, tired 0.05, distracted 0.05, 12.3ms
# Speed: 2.9ms preprocess, 12.3ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.93, tired 0.04, distracted 0.03, 12.6ms
# Speed: 5.0ms preprocess, 12.6ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
#
# 0: 128x128 focus 0.89, distracted 0.06, tired 0.05, 13.0ms
# Speed: 5.0ms preprocess, 13.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
